# %%
from backpack_predictor import prepare_data
from backpack_predictor.features import target, baseline_features, feature_list, cat_cols

# %load_ext autoreload
# %autoreload 2

from datetime import datetime
import time
import numpy as np
import pandas as pd
from scipy.stats import skew, chisquare, kruskal, ks_2samp, chi2_contingency

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import TargetEncoder

import xgboost as xgb
from catboost import CatBoostRegressor

from optuna.integration import XGBoostPruningCallback, CatBoostPruningCallback
import optuna

import warnings
warnings.filterwarnings('ignore')

test_df = pd.read_csv(r'..//data//test.csv')
train_df = pd.read_csv(r'..//data//train.csv')
train_extra_df = pd.read_csv(r'..//data//training_extra.csv')
train_df = pd.concat([train_df, train_extra_df], ignore_index=True)


# Apply function to train and test datasets
train_df = prepare_data(train_df, is_train=True)
test_df = prepare_data(test_df, is_train=False)


# X = train_df.drop(target, axis=1)
# y = train_df[target]

# Ensure categorical features are strings
# X_train.iloc[:, baseline_features] = X_train.iloc[:, baseline_features].astype(str)
# X_val.iloc[:, baseline_features]   = X_val.iloc[:, baseline_features].astype(str)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Next test: Convert cat cols to str

# %%
model_str = "catboost_"
# test_name = "all_features_"
# study_name = "huber_error_"
study_name = "exclude_bin_"
# model_str = "xgb_"
# cols_to_transform = ["weight_capacity"]

TE_features = [
    'weight_capacity', 'compartments', 'wc_decimal_count', 'brand', 'color',
    'laptop_compartment', 'is_waterproof', 'size', 'material', 'style'
]
TE_new_cols = [col + "_te" for col in TE_features]
features = TE_features + TE_new_cols #+ cat_features  
# Exclude these two
features = [col for col in features if col not in ['laptop_compartment', 'is_waterproof']]

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=4444)
data_splits = []

for train_index, val_index in kf.split(train_df):
    train_fold = train_df.iloc[train_index]
    val_fold = train_df.iloc[val_index]

    te = TargetEncoder(target_type="continuous", smooth=20)
    train_fold[TE_new_cols] = (
        te.fit_transform(train_fold[TE_features], train_fold[target])
    )
    val_fold[TE_new_cols] = (
        te.transform(val_fold[TE_features])
    )
    data_splits.append((train_fold, val_fold))

# cat_features_fold = X_train[feature_list].select_dtypes(include=['object', 'category']).columns.tolist()
# cat_feature_indexes_fold = [X_train[feature_list].columns.get_loc(col) for col in cat_features_fold]

# %%
# %%time


def objective(trial):
    params = {
        "random_state": 42,
        "verbose": 0,
        "eval_metric": "RMSE",
        
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.5, log=True),
        "iterations": trial.suggest_int("iterations", 100, 5000),
        "depth": trial.suggest_int("depth", 4, 16),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 1, 50),
        
        # Additional CatBoost parameters with conditionals
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1, log=True),
    }

    # Conditional parameters
    if params["bootstrap_type"] == "Bayesian":
        params["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif params["bootstrap_type"] == "Bernoulli":
        params["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)


    early_stopping_rounds = trial.suggest_int("early_stopping_rounds", 5, 1000)

    rmse_list = []

    for i, (train_fold, val_fold) in enumerate(data_splits, 1):
        model = CatBoostRegressor(**params)
        model.fit(
            train_fold[features], 
            train_fold[target],
            eval_set=[(val_fold[features], val_fold[target])],
            early_stopping_rounds=early_stopping_rounds, 
            callbacks=[CatBoostPruningCallback(trial, "RMSE")],
            use_best_model=True
        )
        preds = model.predict(val_fold[features])
        rmse = root_mean_squared_error(val_fold[target], preds)
        rmse_list.append(rmse)

    return np.mean(rmse_list)


study = optuna.create_study(
        storage=f"sqlite:///..//optuna//{model_str}db.sqlite3",
        study_name=study_name + datetime.now().strftime("%Y-%m-%d_%H-%M"),
        direction="minimize"
)
study.optimize(objective, n_trials=500)

print("\n=========================")
print("Number of finished trials:", len(study.trials))
print("Best trial:", study.best_trial.number)
print("Best value (RMSE):", study.best_trial.value)
print("Best hyperparameters:", study.best_trial.params)
best_params = study.best_trial.params
best_params["random_state"] = 42
best_params["verbose"] = 0
# best_params["eval_metric"] = "RMSE"
best_params
# Out:
# [I 2025-02-17 20:39:45,553] A new study created in RDB with name: exclude_bin_2025-02-17_20-39
# [I 2025-02-17 20:47:40,603] Trial 0 finished with value: 38.9372967545389 and parameters: {'learning_rate': 0.00017478313228379855, 'iterations': 749, 'depth': 5, 'l2_leaf_reg': 7.670495787294963, 'random_strength': 8.797238771028821, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.025133677052251172, 'bagging_temperature': 0.8195094326596841, 'early_stopping_rounds': 806}. Best is trial 0 with value: 38.9372967545389.
# [I 2025-02-17 21:07:42,048] Trial 1 finished with value: 38.71628072407219 and parameters: {'learning_rate': 0.010242011532998915, 'iterations': 1717, 'depth': 16, 'l2_leaf_reg': 3.971414560251838, 'random_strength': 45.16109985956692, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07177834904912217, 'early_stopping_rounds': 427}. Best is trial 1 with value: 38.71628072407219.
# [I 2025-02-17 22:28:28,517] Trial 2 finished with value: 38.718836750284495 and parameters: {'learning_rate': 0.019126141210559867, 'iterations': 4646, 'depth': 4, 'l2_leaf_reg': 1.9840920906163113, 'random_strength': 41.87904083912803, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.023197736045211644, 'early_stopping_rounds': 159}. Best is trial 1 with value: 38.71628072407219.
# [I 2025-02-17 23:22:13,681] Trial 3 finished with value: 38.93678430578939 and parameters: {'learning_rate': 0.00017398499722165963, 'iterations': 3645, 'depth': 14, 'l2_leaf_reg': 9.819904207494378, 'random_strength': 27.00087280313827, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.010947490365060953, 'bagging_temperature': 2.14811973722562, 'early_stopping_rounds': 576}. Best is trial 1 with value: 38.71628072407219.
# [I 2025-02-17 23:53:42,007] Trial 4 finished with value: 38.672612167359816 and parameters: {'learning_rate': 0.3019248507474747, 'iterations': 3407, 'depth': 4, 'l2_leaf_reg': 7.13077595905035, 'random_strength': 4.623510188767504, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.055587717192846206, 'early_stopping_rounds': 508}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-17 23:53:48,604] Trial 5 finished with value: 38.9386801263028 and parameters: {'learning_rate': 0.022780931004049657, 'iterations': 3072, 'depth': 5, 'l2_leaf_reg': 5.2910148729719015, 'random_strength': 25.368575294829835, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.010428252791941038, 'early_stopping_rounds': 793}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-17 23:53:52,521] Trial 6 finished with value: 38.938680126302685 and parameters: {'learning_rate': 0.004937488083818687, 'iterations': 3764, 'depth': 11, 'l2_leaf_reg': 6.45520539076656, 'random_strength': 25.450983174150153, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.013665260421076462, 'subsample': 0.6589452104610921, 'early_stopping_rounds': 605}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-17 23:53:56,486] Trial 7 finished with value: 38.93868012630261 and parameters: {'learning_rate': 0.0010116530431516684, 'iterations': 1818, 'depth': 15, 'l2_leaf_reg': 2.7713822743408256, 'random_strength': 22.58403020810419, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03118897946328934, 'subsample': 0.9352502595977011, 'early_stopping_rounds': 610}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-17 23:58:49,875] Trial 8 finished with value: 38.75923629282865 and parameters: {'learning_rate': 0.025247144636066858, 'iterations': 726, 'depth': 6, 'l2_leaf_reg': 2.072456781219029, 'random_strength': 19.18557364643656, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04500235406569314, 'early_stopping_rounds': 934}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-17 23:58:56,495] Trial 9 finished with value: 38.9386801263028 and parameters: {'learning_rate': 0.022494831093459552, 'iterations': 3367, 'depth': 7, 'l2_leaf_reg': 1.477960957644001, 'random_strength': 24.419210748761586, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.012176084777808922, 'early_stopping_rounds': 751}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:01:32,399] Trial 10 finished with value: 38.682068842742964 and parameters: {'learning_rate': 0.3563094150569329, 'iterations': 4868, 'depth': 9, 'l2_leaf_reg': 8.64584676814985, 'random_strength': 1.4920471711738394, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09435644932427549, 'subsample': 0.11121242965128715, 'early_stopping_rounds': 202}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:03:57,143] Trial 11 finished with value: 38.68758335984526 and parameters: {'learning_rate': 0.4857356175493194, 'iterations': 4807, 'depth': 9, 'l2_leaf_reg': 8.775681980891616, 'random_strength': 1.0239534478644383, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09974894388844675, 'subsample': 0.10112188556553522, 'early_stopping_rounds': 270}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:04:01,276] Trial 12 finished with value: 38.91052224440348 and parameters: {'learning_rate': 0.4425098050496179, 'iterations': 4305, 'depth': 11, 'l2_leaf_reg': 7.2852897296821855, 'random_strength': 1.0887449818259292, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05507360111817953, 'subsample': 0.10332207205242662, 'early_stopping_rounds': 356}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:07:51,936] Trial 13 finished with value: 38.67370490279951 and parameters: {'learning_rate': 0.12471442265096574, 'iterations': 2481, 'depth': 8, 'l2_leaf_reg': 8.764501645486396, 'random_strength': 10.676033001023997, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09150007373259764, 'subsample': 0.2587334183996247, 'early_stopping_rounds': 17}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:10:32,177] Trial 14 finished with value: 38.7403190215147 and parameters: {'learning_rate': 0.1014145371533224, 'iterations': 2563, 'depth': 7, 'l2_leaf_reg': 5.348800508614609, 'random_strength': 12.674418413523712, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.051155481017827444, 'bagging_temperature': 9.958247572822334, 'early_stopping_rounds': 9}. Best is trial 4 with value: 38.672612167359816.
# [I 2025-02-18 00:18:05,675] Trial 15 finished with value: 38.67126257527179 and parameters: {'learning_rate': 0.09680081274642252, 'iterations': 2072, 'depth': 13, 'l2_leaf_reg': 6.510816694232317, 'random_strength': 11.751707193631429, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06969038174322524, 'early_stopping_rounds': 30}. Best is trial 15 with value: 38.67126257527179.
# [I 2025-02-18 00:30:34,271] Trial 16 finished with value: 38.670352821945116 and parameters: {'learning_rate': 0.09789861061610167, 'iterations': 1506, 'depth': 13, 'l2_leaf_reg': 4.184758064220479, 'random_strength': 16.327476922882344, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06550588893138466, 'early_stopping_rounds': 411}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:30:38,819] Trial 17 finished with value: 38.93549841878533 and parameters: {'learning_rate': 0.08037193463511116, 'iterations': 1437, 'depth': 13, 'l2_leaf_reg': 4.071966054170886, 'random_strength': 33.14919793765488, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03495436725460767, 'early_stopping_rounds': 100}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:30:45,531] Trial 18 finished with value: 38.93868012630266 and parameters: {'learning_rate': 0.0029390504454628688, 'iterations': 1277, 'depth': 13, 'l2_leaf_reg': 4.027151143697694, 'random_strength': 14.885293644758109, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.07046188268335885, 'early_stopping_rounds': 300}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:30:49,995] Trial 19 finished with value: 38.93835282923535 and parameters: {'learning_rate': 0.06236646724623548, 'iterations': 259, 'depth': 12, 'l2_leaf_reg': 6.035258458748417, 'random_strength': 32.484294903286525, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07312021251065834, 'early_stopping_rounds': 407}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:30:54,364] Trial 20 finished with value: 38.93689153070702 and parameters: {'learning_rate': 0.0461890419706912, 'iterations': 2384, 'depth': 16, 'l2_leaf_reg': 4.604738543787773, 'random_strength': 18.072592662073518, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.038634072049152396, 'early_stopping_rounds': 997}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:44:49,151] Trial 21 finished with value: 38.67178167960382 and parameters: {'learning_rate': 0.16837920639342518, 'iterations': 2105, 'depth': 14, 'l2_leaf_reg': 6.860437320782559, 'random_strength': 7.361410809958224, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05998051214094236, 'early_stopping_rounds': 480}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:56:57,019] Trial 22 finished with value: 38.671540162605176 and parameters: {'learning_rate': 0.1609905666859558, 'iterations': 2031, 'depth': 14, 'l2_leaf_reg': 6.353042620667265, 'random_strength': 6.852858166117471, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06318536807668942, 'early_stopping_rounds': 463}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:01,435] Trial 23 finished with value: 38.937425662221585 and parameters: {'learning_rate': 0.17742507720743225, 'iterations': 1273, 'depth': 12, 'l2_leaf_reg': 5.88465244942532, 'random_strength': 15.62122438541358, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07720380165712777, 'early_stopping_rounds': 687}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:05,733] Trial 24 finished with value: 38.93860053191321 and parameters: {'learning_rate': 0.04575448605089313, 'iterations': 2730, 'depth': 14, 'l2_leaf_reg': 3.2251952690036494, 'random_strength': 7.042211456952785, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.043774653424335015, 'early_stopping_rounds': 284}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:12,284] Trial 25 finished with value: 38.91937771147216 and parameters: {'learning_rate': 0.19894331461975895, 'iterations': 1940, 'depth': 15, 'l2_leaf_reg': 4.899653710862061, 'random_strength': 11.998227888496162, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.062008407823989094, 'bagging_temperature': 8.035883587690417, 'early_stopping_rounds': 114}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:18,747] Trial 26 finished with value: 38.93868012630263 and parameters: {'learning_rate': 0.0014239152711081331, 'iterations': 765, 'depth': 11, 'l2_leaf_reg': 7.86399117815005, 'random_strength': 19.79781774291922, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.0467100119209683, 'early_stopping_rounds': 504}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:22,716] Trial 27 finished with value: 38.93860705891874 and parameters: {'learning_rate': 0.04192221468804807, 'iterations': 2181, 'depth': 13, 'l2_leaf_reg': 6.120841663500033, 'random_strength': 15.469900972623353, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08291875050909793, 'early_stopping_rounds': 218}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:26,708] Trial 28 finished with value: 38.93867689530889 and parameters: {'learning_rate': 0.0062740259573300415, 'iterations': 1433, 'depth': 12, 'l2_leaf_reg': 3.0927470084716218, 'random_strength': 5.158163695042974, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.018880655423215948, 'early_stopping_rounds': 402}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:30,662] Trial 29 finished with value: 38.93867653059127 and parameters: {'learning_rate': 0.013281680145981595, 'iterations': 956, 'depth': 10, 'l2_leaf_reg': 7.946111368413147, 'random_strength': 9.387053927857618, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03059939951115779, 'bagging_temperature': 5.311620692764783, 'early_stopping_rounds': 701}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:57:34,662] Trial 30 finished with value: 38.93867954752216 and parameters: {'learning_rate': 0.0003253203313983128, 'iterations': 2866, 'depth': 15, 'l2_leaf_reg': 4.572903910299282, 'random_strength': 31.638521225253335, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06559363817868029, 'early_stopping_rounds': 331}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 00:59:16,330] Trial 31 finished with value: 38.88509961499905 and parameters: {'learning_rate': 0.1858734958712344, 'iterations': 2102, 'depth': 14, 'l2_leaf_reg': 6.773840766245614, 'random_strength': 7.597333825349514, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.061053285638815485, 'early_stopping_rounds': 531}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:21,699] Trial 32 finished with value: 38.6808462329743 and parameters: {'learning_rate': 0.2326985912045304, 'iterations': 1544, 'depth': 16, 'l2_leaf_reg': 6.713376638154792, 'random_strength': 5.610649733218919, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08383128183431467, 'early_stopping_rounds': 448}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:26,095] Trial 33 finished with value: 38.92983819142226 and parameters: {'learning_rate': 0.13176129872727232, 'iterations': 1746, 'depth': 14, 'l2_leaf_reg': 5.525308575982897, 'random_strength': 12.514624737163867, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.054787114771725584, 'early_stopping_rounds': 430}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:30,391] Trial 34 finished with value: 38.93565434596154 and parameters: {'learning_rate': 0.07944541507106284, 'iterations': 2145, 'depth': 13, 'l2_leaf_reg': 7.569228781055966, 'random_strength': 49.838655505367136, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.024304226487703095, 'early_stopping_rounds': 557}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:36,990] Trial 35 finished with value: 38.93868012630331 and parameters: {'learning_rate': 0.038510705926635025, 'iterations': 1028, 'depth': 15, 'l2_leaf_reg': 6.394821238580503, 'random_strength': 9.430057641267924, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.06654057398632657, 'bagging_temperature': 4.947849469567447, 'early_stopping_rounds': 467}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:40,774] Trial 36 finished with value: 38.9386615914848 and parameters: {'learning_rate': 0.010469982655162875, 'iterations': 361, 'depth': 12, 'l2_leaf_reg': 8.152012175816091, 'random_strength': 3.5480447779765014, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08044401678637408, 'early_stopping_rounds': 875}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:45,926] Trial 37 finished with value: 38.92755481212261 and parameters: {'learning_rate': 0.27524207998063316, 'iterations': 2266, 'depth': 14, 'l2_leaf_reg': 5.677393042451962, 'random_strength': 29.06466202077249, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03899167297926412, 'early_stopping_rounds': 627}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:52,539] Trial 38 finished with value: 38.9386801263026 and parameters: {'learning_rate': 0.00011411677673333415, 'iterations': 1834, 'depth': 15, 'l2_leaf_reg': 9.66386122976989, 'random_strength': 21.512326659039367, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.05126346845511199, 'early_stopping_rounds': 368}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:04:56,623] Trial 39 finished with value: 38.933810586919876 and parameters: {'learning_rate': 0.1236052874582466, 'iterations': 3045, 'depth': 16, 'l2_leaf_reg': 7.144479393791653, 'random_strength': 17.605893791567713, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06100284770159249, 'early_stopping_rounds': 661}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:05:00,354] Trial 40 finished with value: 38.93866384561319 and parameters: {'learning_rate': 0.032018770406892584, 'iterations': 1612, 'depth': 13, 'l2_leaf_reg': 5.01606003089234, 'random_strength': 13.925780763040983, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.016867272769001226, 'bagging_temperature': 4.004744003136512, 'early_stopping_rounds': 228}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:08,031] Trial 41 finished with value: 38.885723339245935 and parameters: {'learning_rate': 0.30028008979510007, 'iterations': 3927, 'depth': 4, 'l2_leaf_reg': 6.971092085908156, 'random_strength': 4.29572664743478, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.056367952710825286, 'early_stopping_rounds': 491}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:12,077] Trial 42 finished with value: 38.93617511507029 and parameters: {'learning_rate': 0.06319002137285087, 'iterations': 2688, 'depth': 10, 'l2_leaf_reg': 6.4204298357175045, 'random_strength': 7.229070518493428, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04946713257010562, 'early_stopping_rounds': 556}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:37,874] Trial 43 finished with value: 38.8873528270042 and parameters: {'learning_rate': 0.4940489462653435, 'iterations': 3377, 'depth': 11, 'l2_leaf_reg': 7.321295229561601, 'random_strength': 10.245067481066885, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04211360352283477, 'early_stopping_rounds': 502}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:42,070] Trial 44 finished with value: 38.93625072623144 and parameters: {'learning_rate': 0.3109366256373522, 'iterations': 3286, 'depth': 4, 'l2_leaf_reg': 6.3200004142414254, 'random_strength': 3.2890069783322478, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07238481473962662, 'early_stopping_rounds': 609}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:48,924] Trial 45 finished with value: 38.93868012630436 and parameters: {'learning_rate': 0.17072210964112625, 'iterations': 1953, 'depth': 9, 'l2_leaf_reg': 7.482202189558124, 'random_strength': 6.786314699967585, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.08777474379521442, 'subsample': 0.3550414525977418, 'early_stopping_rounds': 378}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:53,207] Trial 46 finished with value: 38.93509577601676 and parameters: {'learning_rate': 0.09484551515491808, 'iterations': 4209, 'depth': 6, 'l2_leaf_reg': 8.201356300832549, 'random_strength': 11.091416044337407, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.028214470842580972, 'early_stopping_rounds': 765}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:06:57,135] Trial 47 finished with value: 38.93865098127891 and parameters: {'learning_rate': 0.01651247768288735, 'iterations': 2406, 'depth': 14, 'l2_leaf_reg': 4.460912331743086, 'random_strength': 3.0384244985641855, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05687007285745218, 'early_stopping_rounds': 79}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:07:01,064] Trial 48 finished with value: 38.93417925477622 and parameters: {'learning_rate': 0.06387367733332974, 'iterations': 2998, 'depth': 13, 'l2_leaf_reg': 6.7987561315284, 'random_strength': 40.05507826177957, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06728681239282915, 'subsample': 0.23950972254847672, 'early_stopping_rounds': 159}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:07:05,089] Trial 49 finished with value: 38.93769356843305 and parameters: {'learning_rate': 0.13643445527352666, 'iterations': 2027, 'depth': 8, 'l2_leaf_reg': 3.4632341082830704, 'random_strength': 9.254664177484402, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07634316885647713, 'early_stopping_rounds': 850}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:07:11,399] Trial 50 finished with value: 38.93834653782256 and parameters: {'learning_rate': 0.025992429576743366, 'iterations': 3656, 'depth': 12, 'l2_leaf_reg': 9.183648812415544, 'random_strength': 17.18990101317593, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.09706689272956318, 'early_stopping_rounds': 337}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:18,518] Trial 51 finished with value: 38.68235790278883 and parameters: {'learning_rate': 0.3650808403933868, 'iterations': 2518, 'depth': 6, 'l2_leaf_reg': 2.2459825570792766, 'random_strength': 13.644585216854834, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09135176869705136, 'subsample': 0.24061040863937072, 'early_stopping_rounds': 7}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:22,607] Trial 52 finished with value: 38.93032202243366 and parameters: {'learning_rate': 0.12206983601549783, 'iterations': 2354, 'depth': 5, 'l2_leaf_reg': 8.440064274657113, 'random_strength': 11.46044695942569, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07211903055274409, 'subsample': 0.401864266054889, 'early_stopping_rounds': 52}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:26,691] Trial 53 finished with value: 38.88658731641438 and parameters: {'learning_rate': 0.23935982946006876, 'iterations': 2670, 'depth': 8, 'l2_leaf_reg': 8.951143512445647, 'random_strength': 8.049292908681377, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08968150424830056, 'subsample': 0.17875483010218446, 'early_stopping_rounds': 162}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:31,108] Trial 54 finished with value: 38.9314695721572 and parameters: {'learning_rate': 0.08673349173697979, 'iterations': 1728, 'depth': 7, 'l2_leaf_reg': 9.542946791209014, 'random_strength': 6.220195541689194, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06248477261838173, 'subsample': 0.4530372110682702, 'early_stopping_rounds': 54}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:38,373] Trial 55 finished with value: 38.880941468624364 and parameters: {'learning_rate': 0.15837165410349222, 'iterations': 1242, 'depth': 11, 'l2_leaf_reg': 5.107370100996717, 'random_strength': 22.951462668801508, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09985991337715011, 'subsample': 0.15859527764149914, 'early_stopping_rounds': 467}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:43,067] Trial 56 finished with value: 38.93459461761205 and parameters: {'learning_rate': 0.10240174304531535, 'iterations': 3229, 'depth': 5, 'l2_leaf_reg': 5.97258779594989, 'random_strength': 1.905525459839081, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04797004832262214, 'early_stopping_rounds': 130}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:46,737] Trial 57 finished with value: 38.93867920520434 and parameters: {'learning_rate': 0.05852789244334612, 'iterations': 2889, 'depth': 13, 'l2_leaf_reg': 5.638484412440738, 'random_strength': 15.923092788252319, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08004587219624479, 'bagging_temperature': 7.487487026501421, 'early_stopping_rounds': 569}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:54,772] Trial 58 finished with value: 38.90214167590757 and parameters: {'learning_rate': 0.22337955535816084, 'iterations': 2428, 'depth': 15, 'l2_leaf_reg': 7.744224845431554, 'random_strength': 10.896395662640728, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05232015560949124, 'early_stopping_rounds': 407}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:08:58,698] Trial 59 finished with value: 38.91565315387091 and parameters: {'learning_rate': 0.38793052537116446, 'iterations': 1438, 'depth': 8, 'l2_leaf_reg': 3.6197587721762794, 'random_strength': 19.725452657965878, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05859624721779076, 'subsample': 0.586867239825655, 'early_stopping_rounds': 243}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:02,502] Trial 60 finished with value: 38.93867310116206 and parameters: {'learning_rate': 0.003955711110598356, 'iterations': 1867, 'depth': 14, 'l2_leaf_reg': 7.098321181712515, 'random_strength': 5.027491815405571, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03585596875149875, 'early_stopping_rounds': 533}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:06,765] Trial 61 finished with value: 38.927726752979204 and parameters: {'learning_rate': 0.23310221246614238, 'iterations': 1607, 'depth': 15, 'l2_leaf_reg': 6.666418401797145, 'random_strength': 8.502287494365376, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08423811837502797, 'early_stopping_rounds': 445}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:10,650] Trial 62 finished with value: 38.93251376905099 and parameters: {'learning_rate': 0.16378983027841726, 'iterations': 1563, 'depth': 16, 'l2_leaf_reg': 1.0439576151137784, 'random_strength': 5.554323346809172, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06631152835721253, 'early_stopping_rounds': 316}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:14,502] Trial 63 finished with value: 38.93695587459567 and parameters: {'learning_rate': 0.2547937025061594, 'iterations': 2205, 'depth': 16, 'l2_leaf_reg': 9.953669859542487, 'random_strength': 13.218500130949556, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07553578315571996, 'early_stopping_rounds': 457}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:18,417] Trial 64 finished with value: 38.93406943030063 and parameters: {'learning_rate': 0.11511336580377632, 'iterations': 2029, 'depth': 12, 'l2_leaf_reg': 6.067213346550018, 'random_strength': 5.698695234640132, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08411243277212409, 'early_stopping_rounds': 519}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:22,216] Trial 65 finished with value: 38.93867915439041 and parameters: {'learning_rate': 0.0005463511951312611, 'iterations': 1203, 'depth': 14, 'l2_leaf_reg': 6.62464573491953, 'random_strength': 2.449813481713446, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06920268566438119, 'early_stopping_rounds': 392}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:28,210] Trial 66 finished with value: 38.93868012630397 and parameters: {'learning_rate': 0.07390712216904496, 'iterations': 1015, 'depth': 16, 'l2_leaf_reg': 5.300864120688626, 'random_strength': 8.330483503299988, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.06353729979552199, 'early_stopping_rounds': 44}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:32,065] Trial 67 finished with value: 38.935787414528214 and parameters: {'learning_rate': 0.49722896298262487, 'iterations': 1481, 'depth': 7, 'l2_leaf_reg': 5.775228180861022, 'random_strength': 10.087132109030234, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07856729038407925, 'early_stopping_rounds': 185}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:36,178] Trial 68 finished with value: 38.93047856225776 and parameters: {'learning_rate': 0.1961897519405311, 'iterations': 4586, 'depth': 13, 'l2_leaf_reg': 6.930813844768551, 'random_strength': 4.403184101880131, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04420506705093691, 'bagging_temperature': 0.23800754548115322, 'early_stopping_rounds': 641}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:09:39,880] Trial 69 finished with value: 38.938592591233984 and parameters: {'learning_rate': 0.050437375536097624, 'iterations': 554, 'depth': 15, 'l2_leaf_reg': 7.315544237296864, 'random_strength': 14.130956936437984, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08866665632698081, 'early_stopping_rounds': 585}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:10:42,749] Trial 70 finished with value: 38.88553069990412 and parameters: {'learning_rate': 0.3215675629204585, 'iterations': 2554, 'depth': 10, 'l2_leaf_reg': 6.223852415250395, 'random_strength': 12.225250133739273, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05358688217562943, 'early_stopping_rounds': 422}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:13:31,690] Trial 71 finished with value: 38.68060449563129 and parameters: {'learning_rate': 0.37728721296245604, 'iterations': 4900, 'depth': 9, 'l2_leaf_reg': 8.53783772168164, 'random_strength': 1.5585388405637017, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0977592142265644, 'subsample': 0.15871170975367205, 'early_stopping_rounds': 265}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:13:35,543] Trial 72 finished with value: 38.887524939316826 and parameters: {'learning_rate': 0.3883389305340697, 'iterations': 3973, 'depth': 10, 'l2_leaf_reg': 9.003950526938336, 'random_strength': 1.274588178004044, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07427768175065812, 'subsample': 0.16716877412630773, 'early_stopping_rounds': 270}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:13:39,719] Trial 73 finished with value: 38.90617589906033 and parameters: {'learning_rate': 0.14452036630879236, 'iterations': 4941, 'depth': 9, 'l2_leaf_reg': 8.08954953967855, 'random_strength': 6.957320164517009, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09453058279795977, 'subsample': 0.2530549029963914, 'early_stopping_rounds': 484}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:13:43,873] Trial 74 finished with value: 38.93851879022268 and parameters: {'learning_rate': 0.0018616059085704735, 'iterations': 4396, 'depth': 9, 'l2_leaf_reg': 9.330134021666423, 'random_strength': 3.619277736574832, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.058914310393963894, 'subsample': 0.13990861484714479, 'early_stopping_rounds': 355}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:14:48,343] Trial 75 finished with value: 38.83902741686167 and parameters: {'learning_rate': 0.21586949810830663, 'iterations': 1792, 'depth': 12, 'l2_leaf_reg': 8.527800046956388, 'random_strength': 4.883521337851157, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08443662682632996, 'subsample': 0.2933454524000167, 'early_stopping_rounds': 442}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:15:59,535] Trial 76 finished with value: 38.88544837565367 and parameters: {'learning_rate': 0.3055244868767388, 'iterations': 2238, 'depth': 14, 'l2_leaf_reg': 6.500923178801102, 'random_strength': 27.450313427459182, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0703159716435178, 'early_stopping_rounds': 485}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:16:05,668] Trial 77 finished with value: 38.93868012630412 and parameters: {'learning_rate': 0.08245828363905884, 'iterations': 2009, 'depth': 11, 'l2_leaf_reg': 7.627323500158538, 'random_strength': 36.52333036559118, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.09355041552176731, 'subsample': 0.19271503520380764, 'early_stopping_rounds': 99}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:16:09,697] Trial 78 finished with value: 38.93850569250857 and parameters: {'learning_rate': 0.10324020460054244, 'iterations': 2846, 'depth': 9, 'l2_leaf_reg': 8.282096942753272, 'random_strength': 6.366135390667218, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07976384657309217, 'early_stopping_rounds': 295}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:16:13,832] Trial 79 finished with value: 38.931965694289524 and parameters: {'learning_rate': 0.1723677147219118, 'iterations': 4764, 'depth': 13, 'l2_leaf_reg': 7.8332848476716865, 'random_strength': 8.914349146654832, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06492414901341648, 'early_stopping_rounds': 540}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:16:17,818] Trial 80 finished with value: 38.93839598353476 and parameters: {'learning_rate': 0.3846046809944034, 'iterations': 1694, 'depth': 8, 'l2_leaf_reg': 8.74074397963437, 'random_strength': 10.400133951601859, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.010157889298918121, 'bagging_temperature': 2.9613650224610555, 'early_stopping_rounds': 33}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:16:21,831] Trial 81 finished with value: 38.93867987169249 and parameters: {'learning_rate': 0.25137979554315654, 'iterations': 4958, 'depth': 9, 'l2_leaf_reg': 8.814886563108898, 'random_strength': 2.623976673525461, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.021682231109990548, 'subsample': 0.1271726208003983, 'early_stopping_rounds': 194}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:18:34,296] Trial 82 finished with value: 38.68340228041234 and parameters: {'learning_rate': 0.30697230603766407, 'iterations': 4297, 'depth': 10, 'l2_leaf_reg': 8.574190357724744, 'random_strength': 1.4740812241730048, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08705793556405525, 'subsample': 0.12635131602051036, 'early_stopping_rounds': 121}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:24:18,160] Trial 83 finished with value: 38.67344714820276 and parameters: {'learning_rate': 0.13215699003956435, 'iterations': 4480, 'depth': 8, 'l2_leaf_reg': 4.348542046507747, 'random_strength': 3.955520193378643, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09872466879105325, 'subsample': 0.1989172090284074, 'early_stopping_rounds': 70}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:29:27,386] Trial 84 finished with value: 38.67313080183747 and parameters: {'learning_rate': 0.13950494798561536, 'iterations': 4627, 'depth': 8, 'l2_leaf_reg': 4.056471020773575, 'random_strength': 4.144149873291379, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0972705591863349, 'subsample': 0.20857479962764255, 'early_stopping_rounds': 74}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:29:32,400] Trial 85 finished with value: 38.8995279550651 and parameters: {'learning_rate': 0.14789110614991494, 'iterations': 4555, 'depth': 8, 'l2_leaf_reg': 3.8670571732959638, 'random_strength': 4.017807971151413, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09329386641370904, 'subsample': 0.20415011111967457, 'early_stopping_rounds': 70}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:34:12,244] Trial 86 finished with value: 38.673974460260055 and parameters: {'learning_rate': 0.12861838823262733, 'iterations': 4786, 'depth': 7, 'l2_leaf_reg': 4.233764553411775, 'random_strength': 7.752659681430933, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09928491866790727, 'subsample': 0.21228513568979923, 'early_stopping_rounds': 22}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:34:16,343] Trial 87 finished with value: 38.92952009929623 and parameters: {'learning_rate': 0.03400869591015899, 'iterations': 4749, 'depth': 7, 'l2_leaf_reg': 4.431789018248422, 'random_strength': 7.541555040104809, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09918146306597575, 'subsample': 0.29776801324478785, 'early_stopping_rounds': 33}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:34:20,459] Trial 88 finished with value: 38.93868012630355 and parameters: {'learning_rate': 0.05140360353701442, 'iterations': 4052, 'depth': 7, 'l2_leaf_reg': 4.2780318123434045, 'random_strength': 16.500044278659942, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.01458594682317816, 'subsample': 0.2154567494251732, 'early_stopping_rounds': 89}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:34:26,572] Trial 89 finished with value: 38.93868012630394 and parameters: {'learning_rate': 0.07243845277114691, 'iterations': 4435, 'depth': 6, 'l2_leaf_reg': 4.694565612863494, 'random_strength': 11.829322296627039, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.08927608333012216, 'subsample': 0.2711214769612079, 'early_stopping_rounds': 12}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:34:30,421] Trial 90 finished with value: 38.93091978576039 and parameters: {'learning_rate': 0.11062152125965048, 'iterations': 4139, 'depth': 4, 'l2_leaf_reg': 2.819414924735058, 'random_strength': 9.531755906218848, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07645840245053649, 'subsample': 0.33956536451542313, 'early_stopping_rounds': 127}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:13,142] Trial 91 finished with value: 38.674495938702265 and parameters: {'learning_rate': 0.13639901285617492, 'iterations': 4677, 'depth': 8, 'l2_leaf_reg': 4.12770435226853, 'random_strength': 2.920329518659157, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09697922616647618, 'subsample': 0.1588324555535233, 'early_stopping_rounds': 64}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:23,694] Trial 92 finished with value: 38.87224316451761 and parameters: {'learning_rate': 0.12893596718109304, 'iterations': 4639, 'depth': 8, 'l2_leaf_reg': 3.8542523585614696, 'random_strength': 7.702851526621025, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09292730215865998, 'subsample': 0.21448232634180522, 'early_stopping_rounds': 60}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:27,973] Trial 93 finished with value: 38.91840211002403 and parameters: {'learning_rate': 0.08794449174845992, 'iterations': 4814, 'depth': 8, 'l2_leaf_reg': 4.159723275999921, 'random_strength': 6.1194260428688665, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08505670855079639, 'subsample': 0.19108543941863926, 'early_stopping_rounds': 145}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:32,442] Trial 94 finished with value: 38.92664054171486 and parameters: {'learning_rate': 0.18118721889416925, 'iterations': 4498, 'depth': 7, 'l2_leaf_reg': 4.797868036863951, 'random_strength': 14.887693440705803, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06949817627397022, 'subsample': 0.14756752389724867, 'early_stopping_rounds': 5}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:36,439] Trial 95 finished with value: 38.9266915702509 and parameters: {'learning_rate': 0.14199042396170927, 'iterations': 3477, 'depth': 6, 'l2_leaf_reg': 3.64718075812385, 'random_strength': 3.154728681974326, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.058083501940795784, 'subsample': 0.22224195648176445, 'early_stopping_rounds': 81}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:49,750] Trial 96 finished with value: 38.87432811514212 and parameters: {'learning_rate': 0.09489536667079114, 'iterations': 4372, 'depth': 7, 'l2_leaf_reg': 3.1361294201993775, 'random_strength': 6.379994657205054, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09865534422578502, 'subsample': 0.18437337312358743, 'early_stopping_rounds': 90}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:54,374] Trial 97 finished with value: 38.926765053085816 and parameters: {'learning_rate': 0.06564429216833863, 'iterations': 4700, 'depth': 5, 'l2_leaf_reg': 4.987417225094166, 'random_strength': 18.53228462589703, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08116450783050702, 'subsample': 0.2698512949977325, 'early_stopping_rounds': 32}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:39:58,955] Trial 98 finished with value: 38.9287033359481 and parameters: {'learning_rate': 0.12216456063538123, 'iterations': 2268, 'depth': 8, 'l2_leaf_reg': 3.3029603305642654, 'random_strength': 4.509745426138938, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0611224118560611, 'subsample': 0.1243432664204345, 'early_stopping_rounds': 110}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:40:02,885] Trial 99 finished with value: 38.93858706385784 and parameters: {'learning_rate': 0.053710262121726866, 'iterations': 3810, 'depth': 8, 'l2_leaf_reg': 5.434116494671608, 'random_strength': 8.553724582159024, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.048767231192204365, 'early_stopping_rounds': 21}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:40:07,016] Trial 100 finished with value: 38.938425063176894 and parameters: {'learning_rate': 0.1894391240793783, 'iterations': 4993, 'depth': 7, 'l2_leaf_reg': 4.508480788872998, 'random_strength': 5.227709725438848, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07271407803862283, 'bagging_temperature': 6.628027966138139, 'early_stopping_rounds': 62}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:14,253] Trial 101 finished with value: 38.670850766887725 and parameters: {'learning_rate': 0.2196955478452561, 'iterations': 4857, 'depth': 9, 'l2_leaf_reg': 4.2034050956126565, 'random_strength': 2.6610115582477105, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09505538862943519, 'subsample': 0.9760209940469718, 'early_stopping_rounds': 150}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:19,716] Trial 102 finished with value: 38.876604281859194 and parameters: {'learning_rate': 0.2074767904907018, 'iterations': 4656, 'depth': 9, 'l2_leaf_reg': 4.293762526306812, 'random_strength': 2.8930611916213653, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09440372498235187, 'subsample': 0.735998196254908, 'early_stopping_rounds': 108}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:24,401] Trial 103 finished with value: 38.900546880702166 and parameters: {'learning_rate': 0.1594649750202456, 'iterations': 4841, 'depth': 8, 'l2_leaf_reg': 3.8888240609704208, 'random_strength': 3.840919137276569, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0889639637960126, 'subsample': 0.8032970203007994, 'early_stopping_rounds': 174}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:29,384] Trial 104 finished with value: 38.91334517530949 and parameters: {'learning_rate': 0.10492316815232537, 'iterations': 4231, 'depth': 8, 'l2_leaf_reg': 3.659527027248906, 'random_strength': 6.679165264509519, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09060692023729636, 'subsample': 0.4718579550705171, 'early_stopping_rounds': 138}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:33,436] Trial 105 finished with value: 38.921692917955625 and parameters: {'learning_rate': 0.13223956211274474, 'iterations': 4508, 'depth': 9, 'l2_leaf_reg': 4.084040186183383, 'random_strength': 5.17633892851654, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07820233391500232, 'subsample': 0.17033139538659456, 'early_stopping_rounds': 64}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:37,844] Trial 106 finished with value: 38.927775620979745 and parameters: {'learning_rate': 0.24100745362750256, 'iterations': 2148, 'depth': 14, 'l2_leaf_reg': 4.216381045906426, 'random_strength': 2.2872307024288516, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09949370558165095, 'early_stopping_rounds': 43}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:42,168] Trial 107 finished with value: 38.93611500978499 and parameters: {'learning_rate': 0.008000894852090561, 'iterations': 2373, 'depth': 14, 'l2_leaf_reg': 5.166275895129573, 'random_strength': 9.829568107679616, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.081749092918497, 'subsample': 0.2407261368233246, 'early_stopping_rounds': 512}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:48,530] Trial 108 finished with value: 38.93868012630399 and parameters: {'learning_rate': 0.07542400594862056, 'iterations': 1872, 'depth': 13, 'l2_leaf_reg': 4.782070046899019, 'random_strength': 7.319497385950509, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.05481965628193019, 'early_stopping_rounds': 212}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:52,660] Trial 109 finished with value: 38.93868036586018 and parameters: {'learning_rate': 0.19359940985963328, 'iterations': 1332, 'depth': 6, 'l2_leaf_reg': 6.9474071394225465, 'random_strength': 11.188365559369693, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04052088338985962, 'subsample': 0.9518904858869885, 'early_stopping_rounds': 593}. Best is trial 16 with value: 38.670352821945116.
# [I 2025-02-18 01:45:57,811] Trial 110 finished with value: 38.91901852799223 and parameters: {'learning_rate': 0.2871626635580625, 'iterations': 2592, 'depth': 9, 'l2_leaf_reg': 4.016101580927326, 'random_strength': 13.03768733401238, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06688192040771347, 'early_stopping_rounds': 708}. Best is trial 16 with value: 38.670352821945116.
# ...
# [I 2025-02-18 05:06:18,950] Trial 466 finished with value: 38.82693634638626 and parameters: {'learning_rate': 0.2556972164772386, 'iterations': 4698, 'depth': 10, 'l2_leaf_reg': 7.932630984012212, 'random_strength': 1.271287374553569, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09963887184730867, 'subsample': 0.9518512336513646, 'early_stopping_rounds': 611}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:06:23,165] Trial 467 finished with value: 38.913598342461036 and parameters: {'learning_rate': 0.3290444322956306, 'iterations': 4553, 'depth': 10, 'l2_leaf_reg': 7.716012850064993, 'random_strength': 1.9696384112830478, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06554233668976858, 'subsample': 0.8969182536902092, 'early_stopping_rounds': 531}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:06:26,927] Trial 468 finished with value: 38.93828262266491 and parameters: {'learning_rate': 0.2552380522245188, 'iterations': 4473, 'depth': 10, 'l2_leaf_reg': 7.7080588649142925, 'random_strength': 2.3005327546448258, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09966560865625575, 'early_stopping_rounds': 542}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:06:30,841] Trial 469 finished with value: 38.90849591644359 and parameters: {'learning_rate': 0.4171409659722133, 'iterations': 4667, 'depth': 10, 'l2_leaf_reg': 7.592309781368254, 'random_strength': 1.7110952027027155, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06886200677106191, 'subsample': 0.9224142000248114, 'early_stopping_rounds': 513}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:06:35,361] Trial 470 finished with value: 38.88224433506001 and parameters: {'learning_rate': 0.2074179833180387, 'iterations': 4743, 'depth': 10, 'l2_leaf_reg': 7.406720560346297, 'random_strength': 1.3169630710938947, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09256875089324226, 'subsample': 0.9563122098496757, 'early_stopping_rounds': 551}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:37,040] Trial 471 finished with value: 38.75083198089479 and parameters: {'learning_rate': 0.2771824599273429, 'iterations': 4652, 'depth': 11, 'l2_leaf_reg': 7.519495704250783, 'random_strength': 1.1406482806379523, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09996994620201799, 'subsample': 0.8926802391799598, 'early_stopping_rounds': 578}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:40,927] Trial 472 finished with value: 38.93828465198717 and parameters: {'learning_rate': 0.2229773200843168, 'iterations': 4481, 'depth': 10, 'l2_leaf_reg': 7.830503826455393, 'random_strength': 1.0745668045533225, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09344581377372692, 'early_stopping_rounds': 531}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:45,989] Trial 473 finished with value: 38.85600514613827 and parameters: {'learning_rate': 0.33309892448427414, 'iterations': 4785, 'depth': 10, 'l2_leaf_reg': 7.701225117118138, 'random_strength': 2.5495952539579867, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0934167496519689, 'subsample': 0.859404131741976, 'early_stopping_rounds': 497}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:50,497] Trial 474 finished with value: 38.92018696234703 and parameters: {'learning_rate': 0.26168365018871736, 'iterations': 4580, 'depth': 11, 'l2_leaf_reg': 8.045322221642579, 'random_strength': 1.0437109469449908, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05520153069497524, 'subsample': 0.9992166748861177, 'early_stopping_rounds': 512}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:54,306] Trial 475 finished with value: 38.93832214374528 and parameters: {'learning_rate': 0.22619205206421833, 'iterations': 4738, 'depth': 10, 'l2_leaf_reg': 7.562269203609886, 'random_strength': 2.5571588902630493, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09998000642616486, 'early_stopping_rounds': 532}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:10:58,438] Trial 476 finished with value: 38.91635980510966 and parameters: {'learning_rate': 0.37277972122910663, 'iterations': 4353, 'depth': 14, 'l2_leaf_reg': 7.257665910891481, 'random_strength': 22.488008242705746, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05839669588585332, 'subsample': 0.9240130655253779, 'early_stopping_rounds': 553}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:03,857] Trial 477 finished with value: 38.87352933953641 and parameters: {'learning_rate': 0.18313522259889267, 'iterations': 4798, 'depth': 10, 'l2_leaf_reg': 7.171822460577027, 'random_strength': 2.8404824089593204, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08924829504536576, 'subsample': 0.8712042909010981, 'early_stopping_rounds': 596}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:08,675] Trial 478 finished with value: 38.93499431617754 and parameters: {'learning_rate': 0.018312424256646163, 'iterations': 4664, 'depth': 4, 'l2_leaf_reg': 2.9230545159548695, 'random_strength': 2.2596769774684944, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0950395973993181, 'subsample': 0.9559398456468888, 'early_stopping_rounds': 487}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:12,817] Trial 479 finished with value: 38.93861304466881 and parameters: {'learning_rate': 0.2883787328142143, 'iterations': 4554, 'depth': 10, 'l2_leaf_reg': 7.362923072288134, 'random_strength': 2.986279846195729, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0628937239922928, 'bagging_temperature': 6.011123510315803, 'early_stopping_rounds': 458}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:16,914] Trial 480 finished with value: 38.93830998127316 and parameters: {'learning_rate': 0.23501671063653035, 'iterations': 4140, 'depth': 10, 'l2_leaf_reg': 7.103613561915684, 'random_strength': 1.992652161273806, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.092357205932516, 'early_stopping_rounds': 517}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:21,645] Trial 481 finished with value: 38.87073256968934 and parameters: {'learning_rate': 0.31577600937599054, 'iterations': 4833, 'depth': 5, 'l2_leaf_reg': 7.376105810799294, 'random_strength': 1.0063081213385556, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09567268249409638, 'subsample': 0.8247963294580078, 'early_stopping_rounds': 666}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:27,930] Trial 482 finished with value: 38.93868012630621 and parameters: {'learning_rate': 0.19460230932272285, 'iterations': 4684, 'depth': 10, 'l2_leaf_reg': 7.650910488447848, 'random_strength': 2.7469706591862972, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.08809154765094235, 'subsample': 0.14103231095991994, 'early_stopping_rounds': 564}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:33,030] Trial 483 finished with value: 38.85849041278546 and parameters: {'learning_rate': 0.2622899313307089, 'iterations': 4420, 'depth': 9, 'l2_leaf_reg': 7.096757658725826, 'random_strength': 3.377790154646722, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09546666297937755, 'subsample': 0.9087418028940177, 'early_stopping_rounds': 482}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:37,565] Trial 484 finished with value: 38.93836752104996 and parameters: {'learning_rate': 0.17095194787088103, 'iterations': 4842, 'depth': 10, 'l2_leaf_reg': 7.810579884506987, 'random_strength': 1.0629648605504542, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0909598497833035, 'early_stopping_rounds': 448}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:11:42,480] Trial 485 finished with value: 38.93045122244136 and parameters: {'learning_rate': 0.02453607066710834, 'iterations': 4761, 'depth': 11, 'l2_leaf_reg': 3.5452305503754213, 'random_strength': 2.0551802016786707, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08565201073313514, 'subsample': 0.9986120649623406, 'early_stopping_rounds': 493}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:03,538] Trial 486 finished with value: 38.80805866079333 and parameters: {'learning_rate': 0.37715574528444784, 'iterations': 4632, 'depth': 9, 'l2_leaf_reg': 7.448413758747818, 'random_strength': 3.361316711323627, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0996700027984468, 'subsample': 0.8789501617429929, 'early_stopping_rounds': 540}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:07,488] Trial 487 finished with value: 38.938641144275536 and parameters: {'learning_rate': 0.23054825802142162, 'iterations': 4499, 'depth': 10, 'l2_leaf_reg': 6.996891062059115, 'random_strength': 2.05393464944886, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04715575998348369, 'subsample': 0.9645020390979525, 'early_stopping_rounds': 471}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:11,443] Trial 488 finished with value: 38.93822015906792 and parameters: {'learning_rate': 0.30353359252667, 'iterations': 4727, 'depth': 10, 'l2_leaf_reg': 8.111498241505496, 'random_strength': 2.742528637031894, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07936458623049163, 'early_stopping_rounds': 504}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:16,005] Trial 489 finished with value: 38.88559511322158 and parameters: {'learning_rate': 0.2043604953169035, 'iterations': 3989, 'depth': 10, 'l2_leaf_reg': 7.650143378799832, 'random_strength': 4.095136919918682, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09194210194587894, 'subsample': 0.922630961437616, 'early_stopping_rounds': 625}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:20,037] Trial 490 finished with value: 38.91728870676799 and parameters: {'learning_rate': 0.27164366981616184, 'iterations': 4864, 'depth': 13, 'l2_leaf_reg': 3.2288291728546166, 'random_strength': 1.9727007975524624, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07184886178327922, 'subsample': 0.8410054996635429, 'early_stopping_rounds': 520}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:26,158] Trial 491 finished with value: 38.817505461404984 and parameters: {'learning_rate': 0.46158495739648586, 'iterations': 4589, 'depth': 10, 'l2_leaf_reg': 7.274963283641437, 'random_strength': 3.4787171580154994, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09600405730779886, 'subsample': 0.1000493295985231, 'early_stopping_rounds': 429}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:30,009] Trial 492 finished with value: 38.938400892350714 and parameters: {'learning_rate': 0.17126443613293915, 'iterations': 4888, 'depth': 11, 'l2_leaf_reg': 6.944091962739646, 'random_strength': 2.075149576240012, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09992640145817697, 'early_stopping_rounds': 475}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:35,001] Trial 493 finished with value: 38.835089816677275 and parameters: {'learning_rate': 0.34517565130032984, 'iterations': 4757, 'depth': 9, 'l2_leaf_reg': 7.138288547309478, 'random_strength': 3.018829933110334, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08844844765509416, 'subsample': 0.7640317419017232, 'early_stopping_rounds': 418}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:39,439] Trial 494 finished with value: 38.890933321637135 and parameters: {'learning_rate': 0.2217739428776294, 'iterations': 1946, 'depth': 10, 'l2_leaf_reg': 7.451243557486407, 'random_strength': 18.0517112001036, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09995165798314615, 'subsample': 0.9567094027277919, 'early_stopping_rounds': 572}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:43,140] Trial 495 finished with value: 38.9382803702746 and parameters: {'learning_rate': 0.2569264740454024, 'iterations': 4626, 'depth': 10, 'l2_leaf_reg': 6.829522443658334, 'random_strength': 4.215081091028891, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08215794518039819, 'early_stopping_rounds': 453}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:48,019] Trial 496 finished with value: 38.869226821672015 and parameters: {'learning_rate': 0.19689012660748678, 'iterations': 4831, 'depth': 11, 'l2_leaf_reg': 2.0818743572882394, 'random_strength': 2.1018264808210114, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09425316570541259, 'subsample': 0.8850557241289931, 'early_stopping_rounds': 503}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:51,888] Trial 497 finished with value: 38.93868054750918 and parameters: {'learning_rate': 0.30693669586489697, 'iterations': 4927, 'depth': 14, 'l2_leaf_reg': 7.337253176436858, 'random_strength': 4.971853634299453, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.035808797958531424, 'subsample': 0.8285084379792613, 'early_stopping_rounds': 532}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:55,949] Trial 498 finished with value: 38.920014222133176 and parameters: {'learning_rate': 0.23191439643773967, 'iterations': 4716, 'depth': 10, 'l2_leaf_reg': 7.987018851738164, 'random_strength': 1.1995452565095839, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06766690165219222, 'subsample': 0.9063901785883756, 'early_stopping_rounds': 544}. Best is trial 135 with value: 38.67017059486748.
# [I 2025-02-18 05:12:59,720] Trial 499 finished with value: 38.938426091103395 and parameters: {'learning_rate': 0.15442159236395267, 'iterations': 4511, 'depth': 10, 'l2_leaf_reg': 7.057269114622222, 'random_strength': 25.482037528955004, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06062489545929541, 'early_stopping_rounds': 457}. Best is trial 135 with value: 38.67017059486748.
# =========================
# Number of finished trials: 500
# Best trial: 135
# Best value (RMSE): 38.67017059486748
# Best hyperparameters: {'learning_rate': 0.17544191615318724, 'iterations': 4642, 'depth': 8, 'l2_leaf_reg': 7.445452183694891, 'random_strength': 1.1159002397721798, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09509017842675167, 'subsample': 0.5653623630552336, 'early_stopping_rounds': 469}
# CPU times: total: 11h 15min 42s
# Wall time: 8h 33min 15s
# {'learning_rate': 0.17544191615318724,
#  'iterations': 4642,
#  'depth': 8,
#  'l2_leaf_reg': 7.445452183694891,
#  'random_strength': 1.1159002397721798,
#  'bootstrap_type': 'Bernoulli',
#  'boosting_type': 'Plain',
#  'colsample_bylevel': 0.09509017842675167,
#  'subsample': 0.5653623630552336,
#  'early_stopping_rounds': 469,
#  'random_state': 42,
#  'verbose': 0}

# %%
for i, (train_fold, val_fold) in enumerate(data_splits, 1):
    break

final_model = CatBoostRegressor(**best_params)
final_model.fit(
    train_fold[features], 
    train_fold[target], 
    # cat_features=cat_feature_indexes,  # remove or adjust if you don't have categorical features
    verbose=0
)

feature_importances = final_model.get_feature_importance()

# Create a DataFrame for easy visualization
feat_imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=True)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(feat_imp_df['Feature'], feat_imp_df['Importance'], color='skyblue')
plt.xlabel('Importance Score')
plt.title('Feature Importance for the Best CatBoost Model')
plt.tight_layout()
plt.show()

# %%
train_fold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3195454 entries, 0 to 3994317
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   brand                  int32
#  1   material               int32
#  2   size                   int32
#  3   compartments           int32
#  4   laptop_compartment     int32
#  5   is_waterproof          int32
#  6   style                  int32
#  7   color                  int32
#  8   weight_capacity        float64
#  9   price                  float64
#  10  wc_decimal_count       int64
#  11  weight_capacity_te     float64
#  12  compartments_te        float64
#  13  wc_decimal_count_te    float64
#  14  brand_te               float64
#  15  color_te               float64
#  16  laptop_compartment_te  float64
#  17  is_waterproof_te       float64
#  18  size_te                float64
#  19  material_te            float64
#  20  style_te               float64
# dtypes: float64(12), int32(8), int64(1)
# memory usage: 438.8 MB

# %%
feature_importances
# Out:
# array([ 6.58272533,  4.2668661 ,  3.41753314,  4.10408261,  3.99456259,
#         2.47297798,  3.08848136,  4.08554749,  4.1098398 ,  3.18288002,
#        28.40422345,  3.48873128,  2.9618188 ,  3.68252765,  4.34456307,
#         3.57995982,  3.82435874,  3.73508638,  3.5371181 ,  3.13611626])

# %%
features
# Out:
# ['weight_capacity',
#  'compartments',
#  'wc_decimal_count',
#  'brand',
#  'color',
#  'laptop_compartment',
#  'is_waterproof',
#  'size',
#  'material',
#  'style',
#  'weight_capacity_te',
#  'compartments_te',
#  'wc_decimal_count_te',
#  'brand_te',
#  'color_te',
#  'laptop_compartment_te',
#  'is_waterproof_te',
#  'size_te',
#  'material_te',
#  'style_te']

# %%
feature_importances = final_model.get_feature_importance()

# Create a DataFrame for easy visualization
feat_imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=True)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(feat_imp_df['Feature'], feat_imp_df['Importance'], color='skyblue')
plt.xlabel('Importance Score')
plt.title('Feature Importance for the Best CatBoost Model')
plt.tight_layout()
plt.show()
