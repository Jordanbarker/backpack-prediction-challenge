# %%
from backpack_predictor import prepare_data
from backpack_predictor.features import target, baseline_features, feature_list, cat_cols

# %load_ext autoreload
# %autoreload 2

from datetime import datetime
import time
import numpy as np
import pandas as pd
from scipy.stats import skew, chisquare, kruskal, ks_2samp, chi2_contingency

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import TargetEncoder

import xgboost as xgb
from catboost import CatBoostRegressor

from optuna.integration import XGBoostPruningCallback, CatBoostPruningCallback
import optuna

import warnings
warnings.filterwarnings('ignore')

test_df = pd.read_csv(r'..//data//test.csv')
train_df = pd.read_csv(r'..//data//train.csv')
train_extra_df = pd.read_csv(r'..//data//training_extra.csv')
train_df = pd.concat([train_df, train_extra_df], ignore_index=True)


# Apply function to train and test datasets
train_df = prepare_data(train_df, is_train=True)
test_df = prepare_data(test_df, is_train=False)


X = train_df.drop(target, axis=1)
y = train_df[target]

# Ensure categorical features are strings
# X_train.iloc[:, baseline_features] = X_train.iloc[:, baseline_features].astype(str)
# X_val.iloc[:, baseline_features]   = X_val.iloc[:, baseline_features].astype(str)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Next test: Convert cat cols to str

# %%
model_str = "catboost_"
# test_name = "all_features_"
# study_name = "huber_error_"
study_name = "all_features_"
# model_str = "xgb_"
# cols_to_transform = ["weight_capacity"]

TE_features = [
    'weight_capacity', 'compartments', 'wc_decimal_count', 'brand', 'color',
    'laptop_compartment', 'is_waterproof', 'size', 'material', 'style'
]
TE_new_cols = [col + "_te" for col in TE_features]
features = TE_features + TE_new_cols #+ cat_features

# %%
# Ensure categorical features are strings
# X_train.iloc[:, cat_feature_indexes] = X_train.iloc[:, cat_feature_indexes].astype(str)
# X_val.iloc[:, cat_feature_indexes]   = X_val.iloc[:, cat_feature_indexes].astype(str)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=4444)
data_splits = []

for train_index, val_index in kf.split(train_df):
    train_fold = train_df.iloc[train_index]
    val_fold = train_df.iloc[val_index]

    te = TargetEncoder(target_type="continuous", smooth=20)
    train_fold[TE_new_cols] = (
        te.fit_transform(train_fold[TE_features], train_fold[target])
    )
    val_fold[TE_new_cols] = (
        te.transform(val_fold[TE_features])
    )
    data_splits.append((train_fold, val_fold))

# cat_features_fold = X_train[feature_list].select_dtypes(include=['object', 'category']).columns.tolist()
# cat_feature_indexes_fold = [X_train[feature_list].columns.get_loc(col) for col in cat_features_fold]

# %%
train_fold
# Out:
#          brand  material  size  compartments  laptop_compartment  \
# 1            3         3     0            10                   1
# 2            4         0     0             2                   1
# 3            2         1     0             8                   1
# 4            0         3     1             1                   1
# 5            2         3     1            10                   0
# ...        ...       ...   ...           ...                 ...
# 3994312      3         2     2             6                   1
# 3994313      2         3    -1             3                   1
# 3994315      3         3     2            10                   0
# 3994316      1         3    -1             2                   0
# 3994317      4         2     1             2                   1
#
#          is_waterproof  style  color  weight_capacity      price  ...  \
# 1                    1      1      4        27.078537   68.88056  ...
# 2                    0      1      2        16.643760   39.17320  ...
# 3                    0      1      4        12.937220   80.60793  ...
# 4                    1      1      4        17.749338   86.02312  ...
# 5                    1     -1      0         7.241812   20.01553  ...
# ...                ...    ...    ...              ...        ...  ...
# 3994312              1      0      2        16.641739   31.52978  ...
# 3994313              1      1      5        28.098120  104.74460  ...
# 3994315              0      0      2        17.037708  148.18470  ...
# 3994316              0      0      1        28.783339   22.32269  ...
# 3994317              0      0      5        23.076169  107.61199  ...
#
#          weight_capacity_te  compartments_te  wc_decimal_count_te   brand_te  \
# 1                 81.366852        81.580327            81.759001  81.754752
# 2                 81.360479        81.650944            81.065930  82.092617
# 3                 81.366852        81.655326            81.076859  81.305264
# 4                 81.366852        80.991530            81.076859  80.489370
# 5                 79.420476        81.539722            81.065930  81.254465
# ...                     ...              ...                  ...        ...
# 3994312           81.383158        81.683350            81.789002  81.816101
# 3994313           78.439504        81.126981            81.076859  81.305264
# 3994315           71.988649        81.603297            81.080382  81.816101
# 3994316           69.508957        81.711873            81.759001  81.217799
# 3994317           85.956132        81.711873            81.759001  82.122428
#
#           color_te  laptop_compartment_te  is_waterproof_te    size_te  \
# 1        82.229466              81.412775         81.429519  81.469800
# 2        81.027925              81.419303         81.419116  81.453061
# 3        82.229466              81.412775         81.426905  81.469800
# 4        82.229466              81.412775         81.429519  81.200999
# 5        80.315461              81.343868         81.422314  81.191530
# ...            ...                    ...               ...        ...
# 3994312  81.055223              81.431287         81.427744  81.645413
# 3994313  81.979104              81.412775         81.429519  78.568378
# 3994315  81.055223              81.378782         81.458413  81.645413
# 3994316  80.959041              81.375882         81.426905  78.568378
# 3994317  81.979104              81.412775         81.426905  81.200999
#
#          material_te   style_te
# 1          81.801712  81.225707
# 2          80.492884  81.205440
# 3          81.127918  81.225707
# 4          81.801712  81.225707
# 5          81.837090  81.841737
# ...              ...        ...
# 3994312    82.049482  81.365647
# 3994313    81.801712  81.225707
# 3994315    81.872618  81.365647
# 3994316    81.801712  81.372545
# 3994317    82.028162  81.372545
#
# [3195455 rows x 21 columns]

# %%
# %%time

from sklearn.metrics import mean_absolute_error

def objective(trial):
    params = {
        "random_state": 42,
        "verbose": 0,
        "eval_metric": "RMSE",
        # "eval_metric": "MAE",
        
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.5, log=True),
        "iterations": trial.suggest_int("iterations", 100, 5000),
        "depth": trial.suggest_int("depth", 4, 16),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 1, 50),
        
        # Additional CatBoost parameters with conditionals
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1, log=True),
    }

    # Conditional parameters
    if params["bootstrap_type"] == "Bayesian":
        params["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif params["bootstrap_type"] == "Bernoulli":
        params["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)


    early_stopping_rounds = trial.suggest_int("early_stopping_rounds", 5, 1000)

    rmse_list = []

    for i, (train_fold, val_fold) in enumerate(data_splits, 1):
        model = CatBoostRegressor(**params)
        model.fit(
            train_fold[features], 
            train_fold[target],
            # cat_features=cat_feature_indexes_fold,
            eval_set=[(val_fold[features], val_fold[target])],
            early_stopping_rounds=early_stopping_rounds, 
            # callbacks=[CatBoostPruningCallback(trial, "MAE")],
            callbacks=[CatBoostPruningCallback(trial, "RMSE")],
            use_best_model=True
        )
        preds = model.predict(val_fold[features])
        rmse = root_mean_squared_error(val_fold[target], preds)
        # rmse = mean_absolute_error(val_fold[target], preds)
        rmse_list.append(rmse)

    return np.mean(rmse_list)


study = optuna.create_study(
        storage=f"sqlite:///..//optuna//{model_str}db.sqlite3",
        study_name=study_name + datetime.now().strftime("%Y-%m-%d_%H-%M"),
        direction="minimize"
)
study.optimize(objective, n_trials=500)

print("\n=========================")
print("Number of finished trials:", len(study.trials))
print("Best trial:", study.best_trial.number)
print("Best value (RMSE):", study.best_trial.value)
print("Best hyperparameters:", study.best_trial.params)
best_params = study.best_trial.params
best_params["random_state"] = 42
best_params["verbose"] = 0
# best_params["eval_metric"] = "RMSE"
best_params
# Out:
# [I 2025-02-17 07:47:41,819] A new study created in RDB with name: mae_2025-02-17_07-47
# [I 2025-02-17 09:08:04,463] Trial 0 finished with value: 38.68320495563506 and parameters: {'learning_rate': 0.03412989003107908, 'iterations': 4483, 'depth': 8, 'l2_leaf_reg': 7.190688050519597, 'random_strength': 21.465406132941617, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.04310753570765555, 'subsample': 0.10145078569847928, 'early_stopping_rounds': 737}. Best is trial 0 with value: 38.68320495563506.
# [I 2025-02-17 09:40:08,794] Trial 1 finished with value: 38.93604287273599 and parameters: {'learning_rate': 0.0002133146788155161, 'iterations': 3262, 'depth': 15, 'l2_leaf_reg': 1.5951701655470352, 'random_strength': 49.597530476096864, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.013894010279813485, 'bagging_temperature': 1.4655618834279782, 'early_stopping_rounds': 650}. Best is trial 0 with value: 38.68320495563506.
# [I 2025-02-17 09:50:36,705] Trial 2 finished with value: 38.67168122802259 and parameters: {'learning_rate': 0.24665670782486956, 'iterations': 4469, 'depth': 12, 'l2_leaf_reg': 5.788398385844328, 'random_strength': 35.169068482278604, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04811465917313007, 'early_stopping_rounds': 245}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 09:52:25,079] Trial 3 finished with value: 38.93860043533542 and parameters: {'learning_rate': 0.00017770949405823485, 'iterations': 167, 'depth': 16, 'l2_leaf_reg': 6.374799739252384, 'random_strength': 27.61098205584222, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.01164259035318483, 'subsample': 0.28533371675736435, 'early_stopping_rounds': 127}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 10:53:57,499] Trial 4 finished with value: 38.86271959720468 and parameters: {'learning_rate': 0.002032540439563848, 'iterations': 2667, 'depth': 9, 'l2_leaf_reg': 8.334242273388297, 'random_strength': 47.22364605009454, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.03756175229149487, 'bagging_temperature': 2.489509553502752, 'early_stopping_rounds': 870}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 10:54:02,830] Trial 5 finished with value: 38.9386801263026 and parameters: {'learning_rate': 0.00020379125847954656, 'iterations': 3988, 'depth': 13, 'l2_leaf_reg': 5.5804069840427495, 'random_strength': 20.176922656465713, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.011766861199141727, 'subsample': 0.1677062073283063, 'early_stopping_rounds': 360}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 10:54:06,943] Trial 6 finished with value: 38.93868006584292 and parameters: {'learning_rate': 0.016741818369133497, 'iterations': 4417, 'depth': 14, 'l2_leaf_reg': 8.487959669786937, 'random_strength': 40.836627626384455, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.010713510570165225, 'early_stopping_rounds': 343}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 10:54:13,374] Trial 7 finished with value: 38.93868012630265 and parameters: {'learning_rate': 0.002609023539243269, 'iterations': 3731, 'depth': 6, 'l2_leaf_reg': 8.858538196317298, 'random_strength': 12.778183081931216, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.044466240089241264, 'early_stopping_rounds': 39}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:04:42,176] Trial 8 finished with value: 38.678825886988676 and parameters: {'learning_rate': 0.16111665632584304, 'iterations': 3012, 'depth': 14, 'l2_leaf_reg': 3.1711740033581473, 'random_strength': 14.087022927711903, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08961725129847503, 'early_stopping_rounds': 858}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:04:49,102] Trial 9 finished with value: 38.93866457164624 and parameters: {'learning_rate': 0.0013207928162088766, 'iterations': 2575, 'depth': 16, 'l2_leaf_reg': 5.211018795501113, 'random_strength': 34.408177202527526, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.09124730555541519, 'early_stopping_rounds': 222}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:12:48,644] Trial 10 finished with value: 38.688065801513346 and parameters: {'learning_rate': 0.23332279330735478, 'iterations': 1211, 'depth': 11, 'l2_leaf_reg': 3.9987945735179546, 'random_strength': 32.837126557421115, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.023259803327640247, 'early_stopping_rounds': 519}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:23:24,236] Trial 11 finished with value: 38.67777589004881 and parameters: {'learning_rate': 0.27065685964184616, 'iterations': 4954, 'depth': 12, 'l2_leaf_reg': 2.991956723949365, 'random_strength': 1.9129764387850958, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09215776437478736, 'early_stopping_rounds': 929}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:31:55,827] Trial 12 finished with value: 38.678934439625756 and parameters: {'learning_rate': 0.4655865245936954, 'iterations': 4944, 'depth': 11, 'l2_leaf_reg': 1.4977543288529576, 'random_strength': 2.2080538605602067, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06417503883671268, 'early_stopping_rounds': 966}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:05,349] Trial 13 finished with value: 38.909288349630344 and parameters: {'learning_rate': 0.0839084762451017, 'iterations': 1829, 'depth': 12, 'l2_leaf_reg': 3.9342638789457567, 'random_strength': 1.2952093758651333, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.059090573692335835, 'early_stopping_rounds': 473}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:09,833] Trial 14 finished with value: 38.938501483107565 and parameters: {'learning_rate': 0.051732015924943836, 'iterations': 4979, 'depth': 7, 'l2_leaf_reg': 2.9450585618307894, 'random_strength': 9.397372057622864, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06101548404729162, 'early_stopping_rounds': 235}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:13,795] Trial 15 finished with value: 38.93867996867127 and parameters: {'learning_rate': 0.009237632551061506, 'iterations': 3708, 'depth': 10, 'l2_leaf_reg': 4.847517205892904, 'random_strength': 37.5386243380555, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.02758323791280363, 'bagging_temperature': 9.988334906936359, 'early_stopping_rounds': 593}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:18,174] Trial 16 finished with value: 38.93808988951428 and parameters: {'learning_rate': 0.39485257486964276, 'iterations': 4347, 'depth': 12, 'l2_leaf_reg': 6.938566202644316, 'random_strength': 28.138320323051452, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.01929004823107088, 'early_stopping_rounds': 392}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:22,977] Trial 17 finished with value: 38.93858256619531 and parameters: {'learning_rate': 0.11153624931872479, 'iterations': 1845, 'depth': 4, 'l2_leaf_reg': 9.845305375850522, 'random_strength': 41.92846419370038, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07404741196408969, 'early_stopping_rounds': 725}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:27,939] Trial 18 finished with value: 38.93863891173598 and parameters: {'learning_rate': 0.026744369528009227, 'iterations': 3331, 'depth': 10, 'l2_leaf_reg': 2.459988136945211, 'random_strength': 21.70540063637163, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05113478106294938, 'bagging_temperature': 8.292606843306187, 'early_stopping_rounds': 201}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:33,185] Trial 19 finished with value: 38.93775557576952 and parameters: {'learning_rate': 0.005629696154151733, 'iterations': 4936, 'depth': 13, 'l2_leaf_reg': 4.1903055510790015, 'random_strength': 7.023365240856724, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09957380671923476, 'subsample': 0.7835094454160927, 'early_stopping_rounds': 53}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:38,239] Trial 20 finished with value: 38.938338132470136 and parameters: {'learning_rate': 0.0749808388218524, 'iterations': 4234, 'depth': 9, 'l2_leaf_reg': 6.07793780884697, 'random_strength': 31.844268705682907, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03397487494951876, 'early_stopping_rounds': 961}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:32:43,044] Trial 21 finished with value: 38.93823826820028 and parameters: {'learning_rate': 0.18368846012811432, 'iterations': 3249, 'depth': 14, 'l2_leaf_reg': 2.674887585749696, 'random_strength': 15.851112476318262, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07832709716431373, 'early_stopping_rounds': 811}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 11:56:01,407] Trial 22 finished with value: 38.67723873192405 and parameters: {'learning_rate': 0.1711468040397928, 'iterations': 2101, 'depth': 14, 'l2_leaf_reg': 3.434501577516188, 'random_strength': 6.915722778043964, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08123748531251487, 'early_stopping_rounds': 867}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:07,113] Trial 23 finished with value: 38.68272453535602 and parameters: {'learning_rate': 0.4738164541674491, 'iterations': 1966, 'depth': 12, 'l2_leaf_reg': 4.716824409303722, 'random_strength': 5.5868934268243295, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07389604451420281, 'early_stopping_rounds': 975}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:21,151] Trial 24 finished with value: 38.89173108492335 and parameters: {'learning_rate': 0.23086067421155593, 'iterations': 1038, 'depth': 13, 'l2_leaf_reg': 1.0500309666249323, 'random_strength': 10.306083289596797, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04887432408559878, 'early_stopping_rounds': 746}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:25,768] Trial 25 finished with value: 38.9386029534258 and parameters: {'learning_rate': 0.04490859760307537, 'iterations': 2197, 'depth': 15, 'l2_leaf_reg': 2.173555400696125, 'random_strength': 18.266026708307585, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05534333529513764, 'early_stopping_rounds': 619}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:34,476] Trial 26 finished with value: 38.93009816799015 and parameters: {'learning_rate': 0.10698421063816972, 'iterations': 1251, 'depth': 11, 'l2_leaf_reg': 3.6427632665060483, 'random_strength': 4.983504806725771, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.0674527577078703, 'early_stopping_rounds': 891}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:39,117] Trial 27 finished with value: 38.93864717936405 and parameters: {'learning_rate': 0.018936379336696837, 'iterations': 4625, 'depth': 15, 'l2_leaf_reg': 4.519956734338337, 'random_strength': 24.59981941071132, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08852144495384928, 'early_stopping_rounds': 479}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:43,710] Trial 28 finished with value: 38.9380368528554 and parameters: {'learning_rate': 0.23148162208936818, 'iterations': 3814, 'depth': 12, 'l2_leaf_reg': 3.4238979591817187, 'random_strength': 1.2221074283645015, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.039502607197106944, 'subsample': 0.9869516267198253, 'early_stopping_rounds': 803}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:50,477] Trial 29 finished with value: 38.9386801263026 and parameters: {'learning_rate': 0.0004591184700269737, 'iterations': 710, 'depth': 9, 'l2_leaf_reg': 7.44079118340467, 'random_strength': 8.766860394469472, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.03051106293143065, 'bagging_temperature': 5.400161162167661, 'early_stopping_rounds': 684}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:23:55,267] Trial 30 finished with value: 38.93805697212527 and parameters: {'learning_rate': 0.047065175005090984, 'iterations': 4656, 'depth': 13, 'l2_leaf_reg': 5.97514109299382, 'random_strength': 42.000508895186975, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07858785128252589, 'subsample': 0.45718252963649825, 'early_stopping_rounds': 557}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:36:29,596] Trial 31 finished with value: 38.67691864513993 and parameters: {'learning_rate': 0.1404532735567691, 'iterations': 2913, 'depth': 14, 'l2_leaf_reg': 3.1449717052731314, 'random_strength': 13.498949531307957, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08919557466972344, 'early_stopping_rounds': 882}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:29,956] Trial 32 finished with value: 38.675551973371014 and parameters: {'learning_rate': 0.12773149150258467, 'iterations': 2260, 'depth': 14, 'l2_leaf_reg': 2.108783952994696, 'random_strength': 11.890946480558522, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0964324121232497, 'early_stopping_rounds': 785}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:34,306] Trial 33 finished with value: 38.93834972428378 and parameters: {'learning_rate': 0.1335677269778859, 'iterations': 1567, 'depth': 16, 'l2_leaf_reg': 1.9707266594722888, 'random_strength': 11.682413933828895, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07952852487387341, 'early_stopping_rounds': 774}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:38,946] Trial 34 finished with value: 38.9385482475609 and parameters: {'learning_rate': 0.07798178689864887, 'iterations': 2373, 'depth': 15, 'l2_leaf_reg': 1.725367184414407, 'random_strength': 25.26839157737605, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06836990526668557, 'early_stopping_rounds': 838}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:45,951] Trial 35 finished with value: 38.93868012630314 and parameters: {'learning_rate': 0.028886701435166716, 'iterations': 2715, 'depth': 14, 'l2_leaf_reg': 5.446950121463832, 'random_strength': 18.402735771511963, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.017289361655876006, 'bagging_temperature': 5.151359443523956, 'early_stopping_rounds': 711}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:50,133] Trial 36 finished with value: 38.93867793042408 and parameters: {'learning_rate': 0.06185233676892432, 'iterations': 2902, 'depth': 14, 'l2_leaf_reg': 2.5198177092554244, 'random_strength': 14.91138450398261, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.044843867098913893, 'early_stopping_rounds': 669}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:47:54,598] Trial 37 finished with value: 38.93860924388826 and parameters: {'learning_rate': 0.3224294372543103, 'iterations': 2237, 'depth': 16, 'l2_leaf_reg': 6.9842183129243995, 'random_strength': 16.67945342524951, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.05306869552841879, 'subsample': 0.36673948772618764, 'early_stopping_rounds': 901}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:48:01,151] Trial 38 finished with value: 38.93857943733672 and parameters: {'learning_rate': 0.008432278671986532, 'iterations': 1570, 'depth': 13, 'l2_leaf_reg': 3.591314459232569, 'random_strength': 49.26356178305207, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.09582812351973502, 'early_stopping_rounds': 298}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:48:05,537] Trial 39 finished with value: 38.93255833729732 and parameters: {'learning_rate': 0.14101035140649235, 'iterations': 3466, 'depth': 15, 'l2_leaf_reg': 1.182597490217927, 'random_strength': 22.88995256401004, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08747764720339606, 'early_stopping_rounds': 416}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:48:10,064] Trial 40 finished with value: 38.93864762690804 and parameters: {'learning_rate': 0.018676893283681776, 'iterations': 157, 'depth': 15, 'l2_leaf_reg': 7.536750146058882, 'random_strength': 13.189308395108533, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07019496876942485, 'bagging_temperature': 0.6180062836448839, 'early_stopping_rounds': 126}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:58:37,052] Trial 41 finished with value: 38.68303817177457 and parameters: {'learning_rate': 0.2823576809178287, 'iterations': 4227, 'depth': 13, 'l2_leaf_reg': 3.2551723577409986, 'random_strength': 4.292024730367457, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0992018616685304, 'early_stopping_rounds': 914}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:58:41,825] Trial 42 finished with value: 38.92938381710065 and parameters: {'learning_rate': 0.16752818107398598, 'iterations': 2850, 'depth': 11, 'l2_leaf_reg': 3.01949235094379, 'random_strength': 6.093421628121948, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08380725586211656, 'early_stopping_rounds': 925}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:58:59,463] Trial 43 finished with value: 38.88884548078668 and parameters: {'learning_rate': 0.31892805391522155, 'iterations': 2344, 'depth': 14, 'l2_leaf_reg': 2.2011162819989467, 'random_strength': 29.015994413175903, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08357507548724032, 'early_stopping_rounds': 997}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:03,866] Trial 44 finished with value: 38.938316878162496 and parameters: {'learning_rate': 0.10143511842007552, 'iterations': 3074, 'depth': 12, 'l2_leaf_reg': 4.275812489480182, 'random_strength': 8.19380543486753, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06160645506317463, 'early_stopping_rounds': 787}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:31,158] Trial 45 finished with value: 38.8869615956923 and parameters: {'learning_rate': 0.49304711077419044, 'iterations': 4023, 'depth': 13, 'l2_leaf_reg': 5.061784713668173, 'random_strength': 3.7836883501462086, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08974372471839068, 'early_stopping_rounds': 834}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:38,458] Trial 46 finished with value: 38.93868012630478 and parameters: {'learning_rate': 0.20507783997619602, 'iterations': 4589, 'depth': 11, 'l2_leaf_reg': 2.709477127913274, 'random_strength': 11.58265073493695, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.05880629018921004, 'early_stopping_rounds': 859}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:42,666] Trial 47 finished with value: 38.938680099419 and parameters: {'learning_rate': 0.0007336355016708023, 'iterations': 3591, 'depth': 14, 'l2_leaf_reg': 1.6632150486732546, 'random_strength': 36.12898715594369, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07271227132231614, 'early_stopping_rounds': 937}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:46,633] Trial 48 finished with value: 38.93858906821924 and parameters: {'learning_rate': 0.03677124846158741, 'iterations': 513, 'depth': 10, 'l2_leaf_reg': 6.5039270969934355, 'random_strength': 7.835515961345015, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09999478335346142, 'early_stopping_rounds': 876}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:50,516] Trial 49 finished with value: 38.93828710112342 and parameters: {'learning_rate': 0.14096911572296433, 'iterations': 2089, 'depth': 12, 'l2_leaf_reg': 3.7464385806432965, 'random_strength': 44.771024844663565, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.046923177687233204, 'subsample': 0.19535430841798695, 'early_stopping_rounds': 293}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 12:59:55,138] Trial 50 finished with value: 38.938670446573845 and parameters: {'learning_rate': 0.004829577750570202, 'iterations': 1634, 'depth': 16, 'l2_leaf_reg': 2.980773469257719, 'random_strength': 2.645841049591226, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04113191251538559, 'early_stopping_rounds': 5}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:25,619] Trial 51 finished with value: 38.88708643418358 and parameters: {'learning_rate': 0.3226215147331961, 'iterations': 2493, 'depth': 14, 'l2_leaf_reg': 3.2532503279935323, 'random_strength': 14.09783809522461, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08821517138709475, 'early_stopping_rounds': 750}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:29,931] Trial 52 finished with value: 38.938543519375244 and parameters: {'learning_rate': 0.08089256745627642, 'iterations': 4795, 'depth': 13, 'l2_leaf_reg': 2.2712700420355034, 'random_strength': 10.407779153723332, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07937801819056829, 'early_stopping_rounds': 855}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:34,147] Trial 53 finished with value: 38.938091138550035 and parameters: {'learning_rate': 0.18288206720993613, 'iterations': 3167, 'depth': 15, 'l2_leaf_reg': 4.026142553050465, 'random_strength': 18.462068440660087, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06678649428658, 'early_stopping_rounds': 952}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:38,490] Trial 54 finished with value: 38.93857361337738 and parameters: {'learning_rate': 0.0625107718054061, 'iterations': 2712, 'depth': 14, 'l2_leaf_reg': 4.502361192103904, 'random_strength': 29.76934913285307, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09355088304379651, 'early_stopping_rounds': 1000}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:42,918] Trial 55 finished with value: 38.9383926599428 and parameters: {'learning_rate': 0.1150400681985572, 'iterations': 2916, 'depth': 12, 'l2_leaf_reg': 5.813751531889464, 'random_strength': 20.908809652002645, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07498218981454595, 'early_stopping_rounds': 810}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:47,299] Trial 56 finished with value: 38.93868012202391 and parameters: {'learning_rate': 0.00011672577628799284, 'iterations': 4020, 'depth': 6, 'l2_leaf_reg': 1.9482408286012367, 'random_strength': 38.66460148067484, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.024703207325671255, 'early_stopping_rounds': 637}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:51,767] Trial 57 finished with value: 38.93825602724634 and parameters: {'learning_rate': 0.3516280978412588, 'iterations': 1802, 'depth': 13, 'l2_leaf_reg': 1.366916259884397, 'random_strength': 7.131367729797392, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.033979633678174824, 'bagging_temperature': 7.60821142047228, 'early_stopping_rounds': 153}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:00:58,697] Trial 58 finished with value: 38.93868012630499 and parameters: {'learning_rate': 0.22131734182397225, 'iterations': 2503, 'depth': 14, 'l2_leaf_reg': 2.738900777859121, 'random_strength': 11.804032077542889, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.05667964484872859, 'early_stopping_rounds': 900}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:02,982] Trial 59 finished with value: 38.938662131675834 and parameters: {'learning_rate': 0.2596016067396123, 'iterations': 4350, 'depth': 11, 'l2_leaf_reg': 6.50424139138988, 'random_strength': 3.269071677318036, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.01365015161871001, 'early_stopping_rounds': 706}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:08,653] Trial 60 finished with value: 38.920509567868706 and parameters: {'learning_rate': 0.17177178487064151, 'iterations': 4827, 'depth': 8, 'l2_leaf_reg': 5.0312966603368965, 'random_strength': 10.184638726456193, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08352102668306584, 'early_stopping_rounds': 545}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:13,088] Trial 61 finished with value: 38.93834355790432 and parameters: {'learning_rate': 0.10722690233250749, 'iterations': 4978, 'depth': 10, 'l2_leaf_reg': 1.523682456746777, 'random_strength': 2.042908732325778, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09116530200728491, 'early_stopping_rounds': 962}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:17,681] Trial 62 finished with value: 38.93462419234688 and parameters: {'learning_rate': 0.42950053932619014, 'iterations': 4499, 'depth': 11, 'l2_leaf_reg': 1.9721291747490834, 'random_strength': 5.315943382672912, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.061694166869442804, 'early_stopping_rounds': 872}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:22,110] Trial 63 finished with value: 38.93430860548475 and parameters: {'learning_rate': 0.4829993430925834, 'iterations': 4802, 'depth': 12, 'l2_leaf_reg': 3.315803512086137, 'random_strength': 6.1182324673050505, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06379993518282176, 'early_stopping_rounds': 929}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:26,642] Trial 64 finished with value: 38.93540278699909 and parameters: {'learning_rate': 0.25386847132767404, 'iterations': 4181, 'depth': 13, 'l2_leaf_reg': 2.3526565404805773, 'random_strength': 16.51500226328934, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07534279961147543, 'subsample': 0.514927613857035, 'early_stopping_rounds': 763}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:31,427] Trial 65 finished with value: 38.937259438727466 and parameters: {'learning_rate': 0.15164968447221472, 'iterations': 1971, 'depth': 10, 'l2_leaf_reg': 2.883093937788109, 'random_strength': 2.0371853515459293, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08203228354443483, 'early_stopping_rounds': 833}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:35,766] Trial 66 finished with value: 38.93863802066048 and parameters: {'learning_rate': 0.012717568867464179, 'iterations': 3874, 'depth': 12, 'l2_leaf_reg': 5.504365760347516, 'random_strength': 1.0453098181644682, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06538661891622195, 'early_stopping_rounds': 972}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:40,282] Trial 67 finished with value: 38.93714628043655 and parameters: {'learning_rate': 0.36883405202986386, 'iterations': 3350, 'depth': 14, 'l2_leaf_reg': 1.2437220127712054, 'random_strength': 9.645694975739326, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07090752446478307, 'bagging_temperature': 3.217865396266419, 'early_stopping_rounds': 905}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:47,232] Trial 68 finished with value: 38.93868012630432 and parameters: {'learning_rate': 0.09294901116410834, 'iterations': 4527, 'depth': 15, 'l2_leaf_reg': 3.8028144018856294, 'random_strength': 12.819216903464119, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.052446577748753886, 'early_stopping_rounds': 811}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:51,995] Trial 69 finished with value: 38.938586931523716 and parameters: {'learning_rate': 0.0544826259943386, 'iterations': 2633, 'depth': 11, 'l2_leaf_reg': 2.569686458588482, 'random_strength': 26.646539161086373, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09548075347793028, 'early_stopping_rounds': 941}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:01:57,023] Trial 70 finished with value: 38.924328037035224 and parameters: {'learning_rate': 0.19622017770271688, 'iterations': 4760, 'depth': 15, 'l2_leaf_reg': 9.987398880573135, 'random_strength': 32.27881275695977, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08570812169100381, 'early_stopping_rounds': 880}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:02:01,741] Trial 71 finished with value: 38.93649852246547 and parameters: {'learning_rate': 0.3910586115683372, 'iterations': 2042, 'depth': 12, 'l2_leaf_reg': 4.5952629329384145, 'random_strength': 4.921404387268653, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.076054460222844, 'early_stopping_rounds': 998}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:03,623] Trial 72 finished with value: 38.68334176198057 and parameters: {'learning_rate': 0.25997229589216064, 'iterations': 1787, 'depth': 13, 'l2_leaf_reg': 3.565798763273414, 'random_strength': 6.570174935850767, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09233305426065248, 'early_stopping_rounds': 968}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:08,082] Trial 73 finished with value: 38.938464449999344 and parameters: {'learning_rate': 0.13091453445947493, 'iterations': 1945, 'depth': 12, 'l2_leaf_reg': 4.091058058666028, 'random_strength': 8.17647111567616, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07226987492987433, 'early_stopping_rounds': 915}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:12,610] Trial 74 finished with value: 38.93802324124636 and parameters: {'learning_rate': 0.29066515983117686, 'iterations': 2338, 'depth': 11, 'l2_leaf_reg': 3.1577110819572902, 'random_strength': 14.572407078942536, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07742844443320578, 'early_stopping_rounds': 418}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:16,998] Trial 75 finished with value: 38.93350443221827 and parameters: {'learning_rate': 0.48810671043752263, 'iterations': 1442, 'depth': 13, 'l2_leaf_reg': 1.0189811228491628, 'random_strength': 4.248011045366324, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0689357551362989, 'subsample': 0.10993146347978018, 'early_stopping_rounds': 830}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:35,536] Trial 76 finished with value: 38.89063515456394 and parameters: {'learning_rate': 0.37597618729472215, 'iterations': 2147, 'depth': 16, 'l2_leaf_reg': 4.788183918262686, 'random_strength': 8.822252743354284, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09960789694456341, 'early_stopping_rounds': 971}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:40,227] Trial 77 finished with value: 38.9366429054575 and parameters: {'learning_rate': 0.22920436025815216, 'iterations': 4996, 'depth': 14, 'l2_leaf_reg': 3.483596960547004, 'random_strength': 3.025720141354064, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08246215923278245, 'early_stopping_rounds': 861}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:47,634] Trial 78 finished with value: 38.93868012630429 and parameters: {'learning_rate': 0.16525753549140587, 'iterations': 2982, 'depth': 11, 'l2_leaf_reg': 1.9807065847279481, 'random_strength': 11.25127690737479, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.05691984650247261, 'early_stopping_rounds': 777}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:52,021] Trial 79 finished with value: 38.938677406617884 and parameters: {'learning_rate': 0.0017444698429494253, 'iterations': 1298, 'depth': 13, 'l2_leaf_reg': 9.283052550206929, 'random_strength': 23.273833784675993, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08839643736228847, 'bagging_temperature': 6.527070334262515, 'early_stopping_rounds': 599}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:13:56,373] Trial 80 finished with value: 38.93867344473681 and parameters: {'learning_rate': 0.003812894682245901, 'iterations': 2292, 'depth': 9, 'l2_leaf_reg': 1.6960588077644254, 'random_strength': 19.777097411338108, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08075068240941297, 'early_stopping_rounds': 892}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 13:41:26,987] Trial 81 finished with value: 38.68112881028099 and parameters: {'learning_rate': 0.2988630667864956, 'iterations': 4304, 'depth': 12, 'l2_leaf_reg': 4.308470638999172, 'random_strength': 4.37495049073391, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09390576161117462, 'early_stopping_rounds': 923}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:34,876] Trial 82 finished with value: 38.68349816064559 and parameters: {'learning_rate': 0.33030524194482136, 'iterations': 4649, 'depth': 12, 'l2_leaf_reg': 4.248143120370549, 'random_strength': 5.302750009925137, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09472452637453288, 'early_stopping_rounds': 937}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:40,689] Trial 83 finished with value: 38.91109491896682 and parameters: {'learning_rate': 0.21549219635786823, 'iterations': 2796, 'depth': 12, 'l2_leaf_reg': 5.353657789489254, 'random_strength': 3.8781989556427945, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08699319492215597, 'early_stopping_rounds': 982}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:44,927] Trial 84 finished with value: 38.938468713059436 and parameters: {'learning_rate': 0.06598842951132904, 'iterations': 4388, 'depth': 12, 'l2_leaf_reg': 3.9045949936978923, 'random_strength': 6.786715631114514, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09287438059894862, 'early_stopping_rounds': 845}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:49,363] Trial 85 finished with value: 38.93828022236901 and parameters: {'learning_rate': 0.12879950716568445, 'iterations': 4123, 'depth': 14, 'l2_leaf_reg': 5.770304545062885, 'random_strength': 2.0971805411519004, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07872363025477201, 'early_stopping_rounds': 920}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:53,815] Trial 86 finished with value: 38.93782172969676 and parameters: {'learning_rate': 0.281912912331553, 'iterations': 2437, 'depth': 13, 'l2_leaf_reg': 6.194176546080925, 'random_strength': 13.141023036862679, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.048681498617308375, 'early_stopping_rounds': 792}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:12:58,277] Trial 87 finished with value: 38.93751152456939 and parameters: {'learning_rate': 0.41642215633146407, 'iterations': 3470, 'depth': 10, 'l2_leaf_reg': 2.9825094205360565, 'random_strength': 15.799487180363872, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06420518157203325, 'early_stopping_rounds': 870}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:13:02,632] Trial 88 finished with value: 38.93846495900495 and parameters: {'learning_rate': 0.08916625576723614, 'iterations': 4875, 'depth': 4, 'l2_leaf_reg': 4.426318153273336, 'random_strength': 7.887270686276855, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07364249621605141, 'early_stopping_rounds': 951}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:13:06,878] Trial 89 finished with value: 38.93867946909402 and parameters: {'learning_rate': 0.184057872269708, 'iterations': 1676, 'depth': 14, 'l2_leaf_reg': 4.986502003904748, 'random_strength': 30.713549461175297, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.010268956672219364, 'early_stopping_rounds': 358}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:13:11,204] Trial 90 finished with value: 38.93863645704349 and parameters: {'learning_rate': 0.00030757790773262454, 'iterations': 2583, 'depth': 11, 'l2_leaf_reg': 4.747299522742908, 'random_strength': 9.469096790220114, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08606804161662285, 'subsample': 0.22018537956901568, 'early_stopping_rounds': 263}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:23:50,096] Trial 91 finished with value: 38.684570960982775 and parameters: {'learning_rate': 0.3043489230905638, 'iterations': 4721, 'depth': 13, 'l2_leaf_reg': 3.1732822547487114, 'random_strength': 3.762366267428492, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0974081550776578, 'early_stopping_rounds': 910}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:23:54,682] Trial 92 finished with value: 38.936853877659196 and parameters: {'learning_rate': 0.15838900255624813, 'iterations': 4288, 'depth': 15, 'l2_leaf_reg': 2.770951278203324, 'random_strength': 34.329137838401934, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0990289926607515, 'early_stopping_rounds': 889}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:36:50,271] Trial 93 finished with value: 38.68228983294912 and parameters: {'learning_rate': 0.26558484931481535, 'iterations': 4463, 'depth': 13, 'l2_leaf_reg': 3.344316299635598, 'random_strength': 4.906337188874465, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09042013956324198, 'early_stopping_rounds': 944}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:36:57,008] Trial 94 finished with value: 38.93831617330327 and parameters: {'learning_rate': 0.115679775958604, 'iterations': 4460, 'depth': 13, 'l2_leaf_reg': 2.44922722867566, 'random_strength': 1.0240356965443689, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09064913614470166, 'early_stopping_rounds': 951}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:37:03,545] Trial 95 finished with value: 38.936869279649734 and parameters: {'learning_rate': 0.23602899102901242, 'iterations': 3912, 'depth': 12, 'l2_leaf_reg': 3.8055445185522805, 'random_strength': 5.490331782878546, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08185540904951188, 'early_stopping_rounds': 983}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:37:14,697] Trial 96 finished with value: 38.938680126309244 and parameters: {'learning_rate': 0.4909136795497598, 'iterations': 3686, 'depth': 14, 'l2_leaf_reg': 3.40512220229592, 'random_strength': 2.6670855028005653, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.019294705388526005, 'early_stopping_rounds': 926}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:37:22,983] Trial 97 finished with value: 38.93772054613229 and parameters: {'learning_rate': 0.19999886062799233, 'iterations': 4549, 'depth': 15, 'l2_leaf_reg': 2.099858820906368, 'random_strength': 7.228752190752723, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.06941572375991913, 'early_stopping_rounds': 823}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:37:44,546] Trial 98 finished with value: 38.89057647297789 and parameters: {'learning_rate': 0.39935581252391406, 'iterations': 4887, 'depth': 12, 'l2_leaf_reg': 3.5970135995843817, 'random_strength': 6.110647043383793, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08669382491804166, 'bagging_temperature': 3.485631677619171, 'early_stopping_rounds': 856}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:37:53,063] Trial 99 finished with value: 38.93803543851439 and parameters: {'learning_rate': 0.2841565819479949, 'iterations': 4117, 'depth': 14, 'l2_leaf_reg': 5.206884172964575, 'random_strength': 10.917299308502995, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07659241239632089, 'early_stopping_rounds': 884}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:38:00,253] Trial 100 finished with value: 38.93824959282516 and parameters: {'learning_rate': 0.13941514051386517, 'iterations': 2231, 'depth': 13, 'l2_leaf_reg': 3.097149417301781, 'random_strength': 4.640203555037406, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09162439901825448, 'early_stopping_rounds': 169}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:54:56,361] Trial 101 finished with value: 38.68700385030253 and parameters: {'learning_rate': 0.33770655571228825, 'iterations': 4297, 'depth': 13, 'l2_leaf_reg': 2.5965661732684806, 'random_strength': 3.216269234252548, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09685019238584157, 'early_stopping_rounds': 911}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:55:06,031] Trial 102 finished with value: 38.92523422858709 and parameters: {'learning_rate': 0.2584711314959554, 'iterations': 4648, 'depth': 12, 'l2_leaf_reg': 2.846155539535694, 'random_strength': 4.351566100419355, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08417370305638802, 'early_stopping_rounds': 944}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:55:15,729] Trial 103 finished with value: 38.92724806393994 and parameters: {'learning_rate': 0.19627234531818663, 'iterations': 3044, 'depth': 13, 'l2_leaf_reg': 3.3731306107787065, 'random_strength': 2.0396861413160243, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09054940729952979, 'early_stopping_rounds': 62}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:55:43,819] Trial 104 finished with value: 38.88903662863953 and parameters: {'learning_rate': 0.43197209973593675, 'iterations': 1903, 'depth': 14, 'l2_leaf_reg': 1.4572402970198701, 'random_strength': 5.770216792889428, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09482404266749644, 'early_stopping_rounds': 983}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:55:50,923] Trial 105 finished with value: 38.936130026261885 and parameters: {'learning_rate': 0.33599858039021024, 'iterations': 4422, 'depth': 5, 'l2_leaf_reg': 4.136928486630483, 'random_strength': 7.4884208923757205, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.038518664920600784, 'early_stopping_rounds': 930}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:55:57,143] Trial 106 finished with value: 38.938674734833576 and parameters: {'learning_rate': 0.1601526265089119, 'iterations': 4731, 'depth': 11, 'l2_leaf_reg': 4.361061789018528, 'random_strength': 8.812453531525248, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.03530440307826662, 'early_stopping_rounds': 488}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:03,398] Trial 107 finished with value: 38.938362688216706 and parameters: {'learning_rate': 0.1008074831913297, 'iterations': 4203, 'depth': 14, 'l2_leaf_reg': 1.785236217612849, 'random_strength': 4.975242716777563, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07983776240314, 'early_stopping_rounds': 898}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:11,133] Trial 108 finished with value: 38.935718915129314 and parameters: {'learning_rate': 0.23864304063227626, 'iterations': 2058, 'depth': 12, 'l2_leaf_reg': 3.7304474053518426, 'random_strength': 44.134040497893025, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07313655524350617, 'subsample': 0.6607230034762195, 'early_stopping_rounds': 847}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:22,344] Trial 109 finished with value: 38.93868012630484 and parameters: {'learning_rate': 0.12073580480172504, 'iterations': 3791, 'depth': 13, 'l2_leaf_reg': 3.2317888290205703, 'random_strength': 3.4595385268458587, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.029738814838293926, 'early_stopping_rounds': 966}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:28,579] Trial 110 finished with value: 38.93861892711011 and parameters: {'learning_rate': 0.035452152348838466, 'iterations': 2781, 'depth': 11, 'l2_leaf_reg': 2.339134336458074, 'random_strength': 17.314833391437986, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09933366526631084, 'early_stopping_rounds': 444}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:38,936] Trial 111 finished with value: 38.938680126303055 and parameters: {'learning_rate': 0.024209233941863046, 'iterations': 4554, 'depth': 8, 'l2_leaf_reg': 7.395769439321224, 'random_strength': 27.669592381297644, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.04031525593185806, 'subsample': 0.10007154623884465, 'early_stopping_rounds': 736}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:49,118] Trial 112 finished with value: 38.93868012630408 and parameters: {'learning_rate': 0.07982418881800904, 'iterations': 3203, 'depth': 7, 'l2_leaf_reg': 8.330597583722245, 'random_strength': 15.165541357329332, 'bootstrap_type': 'Bernoulli', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.04488155620245928, 'subsample': 0.14757195412258306, 'early_stopping_rounds': 760}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 14:56:59,845] Trial 113 finished with value: 38.93474981372776 and parameters: {'learning_rate': 0.2849917674779792, 'iterations': 3983, 'depth': 8, 'l2_leaf_reg': 7.062013662774066, 'random_strength': 22.791798789291434, 'bootstrap_type': 'MVS', 'boosting_type': 'Ordered', 'colsample_bylevel': 0.08859830231751874, 'early_stopping_rounds': 689}. Best is trial 2 with value: 38.67168122802259.
# ...
# [I 2025-02-17 18:42:25,015] Trial 463 finished with value: 38.93793761345563 and parameters: {'learning_rate': 0.25558457050769634, 'iterations': 2153, 'depth': 10, 'l2_leaf_reg': 3.0424627654340997, 'random_strength': 5.773480045906866, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09607726211822748, 'early_stopping_rounds': 836}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:29,146] Trial 464 finished with value: 38.93448145081662 and parameters: {'learning_rate': 0.4994103974010286, 'iterations': 1961, 'depth': 9, 'l2_leaf_reg': 5.409723304204601, 'random_strength': 15.289157274314526, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09942557077403187, 'early_stopping_rounds': 949}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:33,747] Trial 465 finished with value: 38.92386213738065 and parameters: {'learning_rate': 0.31017864313552806, 'iterations': 1486, 'depth': 15, 'l2_leaf_reg': 2.7242471191865567, 'random_strength': 2.85364833968606, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08629352890405696, 'early_stopping_rounds': 863}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:37,877] Trial 466 finished with value: 38.938322050628265 and parameters: {'learning_rate': 0.1144966034556999, 'iterations': 1017, 'depth': 11, 'l2_leaf_reg': 2.136911193876262, 'random_strength': 4.0899714126183, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0920678994242423, 'early_stopping_rounds': 7}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:42,076] Trial 467 finished with value: 38.935823366274526 and parameters: {'learning_rate': 0.38176719506614387, 'iterations': 2986, 'depth': 12, 'l2_leaf_reg': 6.360543982381808, 'random_strength': 1.0328140821005187, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0813533716503886, 'early_stopping_rounds': 986}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:45,959] Trial 468 finished with value: 38.93816176259449 and parameters: {'learning_rate': 0.17056639818619146, 'iterations': 2060, 'depth': 14, 'l2_leaf_reg': 2.970280320745546, 'random_strength': 6.592847684955169, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08943140934805996, 'early_stopping_rounds': 923}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:50,108] Trial 469 finished with value: 38.93801206952068 and parameters: {'learning_rate': 0.22637025317263795, 'iterations': 2482, 'depth': 11, 'l2_leaf_reg': 5.817305074308715, 'random_strength': 2.1474612645152447, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09489674986515613, 'early_stopping_rounds': 964}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:55,025] Trial 470 finished with value: 38.90962994961384 and parameters: {'learning_rate': 0.4270051146272354, 'iterations': 3147, 'depth': 10, 'l2_leaf_reg': 3.561652845467874, 'random_strength': 4.841611212625109, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08497775624903826, 'early_stopping_rounds': 1000}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:42:59,243] Trial 471 finished with value: 38.923857053333315 and parameters: {'learning_rate': 0.3105527964987983, 'iterations': 4141, 'depth': 11, 'l2_leaf_reg': 3.16457495691586, 'random_strength': 3.0349255223515854, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09991063002836936, 'early_stopping_rounds': 643}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:03,824] Trial 472 finished with value: 38.92057585155183 and parameters: {'learning_rate': 0.3789897732835061, 'iterations': 4213, 'depth': 12, 'l2_leaf_reg': 3.4034598782479955, 'random_strength': 3.712754533825297, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09229304150868238, 'early_stopping_rounds': 953}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:08,022] Trial 473 finished with value: 38.93810778073824 and parameters: {'learning_rate': 0.25923522782618275, 'iterations': 1585, 'depth': 14, 'l2_leaf_reg': 4.992006762769291, 'random_strength': 7.806410210497884, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07531293722074442, 'early_stopping_rounds': 60}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:12,889] Trial 474 finished with value: 38.9004362302302 and parameters: {'learning_rate': 0.43756503034646144, 'iterations': 3849, 'depth': 10, 'l2_leaf_reg': 3.096893187744881, 'random_strength': 5.542964814028544, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08900287901527724, 'early_stopping_rounds': 976}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:17,824] Trial 475 finished with value: 38.913058198468704 and parameters: {'learning_rate': 0.3460128728280342, 'iterations': 4975, 'depth': 11, 'l2_leaf_reg': 2.3659711562296253, 'random_strength': 2.067301802542583, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09507849005135442, 'bagging_temperature': 1.0497687889279872, 'early_stopping_rounds': 931}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:22,187] Trial 476 finished with value: 38.93410088772721 and parameters: {'learning_rate': 0.2983284551450163, 'iterations': 4313, 'depth': 11, 'l2_leaf_reg': 2.86989306154974, 'random_strength': 4.578806798638814, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08655585558219045, 'early_stopping_rounds': 902}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:26,036] Trial 477 finished with value: 38.93867049349399 and parameters: {'learning_rate': 0.002916266689683273, 'iterations': 1312, 'depth': 10, 'l2_leaf_reg': 6.040644534970639, 'random_strength': 3.0125430230993873, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09179379173829331, 'early_stopping_rounds': 879}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:30,403] Trial 478 finished with value: 38.9382415711432 and parameters: {'learning_rate': 0.14221609745549427, 'iterations': 3991, 'depth': 12, 'l2_leaf_reg': 5.559653422658864, 'random_strength': 3.8172947154137447, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0999737930629844, 'early_stopping_rounds': 243}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:34,586] Trial 479 finished with value: 38.936168388765275 and parameters: {'learning_rate': 0.3771898866988672, 'iterations': 4841, 'depth': 11, 'l2_leaf_reg': 3.65032585656093, 'random_strength': 5.897089377095794, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0815290793698234, 'early_stopping_rounds': 982}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:39,851] Trial 480 finished with value: 38.90448120948703 and parameters: {'learning_rate': 0.49545673729382744, 'iterations': 2311, 'depth': 12, 'l2_leaf_reg': 3.252285503409819, 'random_strength': 9.31078198586156, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09400885434832751, 'early_stopping_rounds': 945}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:43,768] Trial 481 finished with value: 38.93835508240258 and parameters: {'learning_rate': 0.20489403499736641, 'iterations': 4079, 'depth': 15, 'l2_leaf_reg': 5.282973404295497, 'random_strength': 14.282362666364357, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.059625547982888896, 'early_stopping_rounds': 965}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:48,033] Trial 482 finished with value: 38.93788303665794 and parameters: {'learning_rate': 0.2777007535592392, 'iterations': 2210, 'depth': 11, 'l2_leaf_reg': 2.606440466946722, 'random_strength': 1.8931591055644577, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08875947764691752, 'early_stopping_rounds': 269}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:52,802] Trial 483 finished with value: 38.909659924962945 and parameters: {'learning_rate': 0.42628141948348997, 'iterations': 4231, 'depth': 10, 'l2_leaf_reg': 3.4619996796598174, 'random_strength': 4.874761218542159, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08533436208294946, 'early_stopping_rounds': 924}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:43:57,228] Trial 484 finished with value: 38.922959845975946 and parameters: {'learning_rate': 0.3352134118463788, 'iterations': 2413, 'depth': 11, 'l2_leaf_reg': 3.0540782070995203, 'random_strength': 2.88169154363392, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09493293314145884, 'early_stopping_rounds': 148}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:02,649] Trial 485 finished with value: 38.90321531892304 and parameters: {'learning_rate': 0.49683457533608605, 'iterations': 4335, 'depth': 14, 'l2_leaf_reg': 5.85614473591089, 'random_strength': 7.057380648558654, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.090248732998018, 'early_stopping_rounds': 987}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:06,618] Trial 486 finished with value: 38.93799855507671 and parameters: {'learning_rate': 0.23159516533503613, 'iterations': 2124, 'depth': 11, 'l2_leaf_reg': 3.3138500113800022, 'random_strength': 3.8722201734259234, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09641439088588591, 'early_stopping_rounds': 298}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:10,782] Trial 487 finished with value: 38.935921169582755 and parameters: {'learning_rate': 0.37400998392831003, 'iterations': 1867, 'depth': 12, 'l2_leaf_reg': 1.9306439401022386, 'random_strength': 1.6095105000931653, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.07917196953582321, 'early_stopping_rounds': 947}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:14,629] Trial 488 finished with value: 38.93868012630816 and parameters: {'learning_rate': 0.2984030908697439, 'iterations': 4159, 'depth': 10, 'l2_leaf_reg': 2.8687555307444397, 'random_strength': 3.238729692011658, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.012893958883499082, 'early_stopping_rounds': 971}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:18,947] Trial 489 finished with value: 38.93839668514619 and parameters: {'learning_rate': 0.17602550809841538, 'iterations': 2527, 'depth': 9, 'l2_leaf_reg': 3.824004159962027, 'random_strength': 30.01685000849831, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0844587306712118, 'early_stopping_rounds': 905}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:26,810] Trial 490 finished with value: 38.88921226685507 and parameters: {'learning_rate': 0.4173177967612377, 'iterations': 3928, 'depth': 14, 'l2_leaf_reg': 5.639802800122338, 'random_strength': 4.795929800797654, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0913392452603892, 'early_stopping_rounds': 224}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:31,217] Trial 491 finished with value: 38.9228458817272 and parameters: {'learning_rate': 0.33621639160833455, 'iterations': 4781, 'depth': 11, 'l2_leaf_reg': 3.195245729262549, 'random_strength': 1.137052785351448, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09996632998950346, 'early_stopping_rounds': 498}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:35,095] Trial 492 finished with value: 38.93828542252029 and parameters: {'learning_rate': 0.2555371962522791, 'iterations': 1413, 'depth': 11, 'l2_leaf_reg': 3.4548864003323443, 'random_strength': 12.912568888471146, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08788816399341647, 'early_stopping_rounds': 948}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:39,141] Trial 493 finished with value: 38.936115505076046 and parameters: {'learning_rate': 0.4083434980675396, 'iterations': 4268, 'depth': 10, 'l2_leaf_reg': 5.47533365255129, 'random_strength': 2.6071486694920942, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.025304021417600676, 'early_stopping_rounds': 814}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:43,286] Trial 494 finished with value: 38.938679488658366 and parameters: {'learning_rate': 0.00019279168665919285, 'iterations': 4104, 'depth': 12, 'l2_leaf_reg': 3.061375903679554, 'random_strength': 5.966370890180869, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09336191592219166, 'early_stopping_rounds': 923}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:47,993] Trial 495 finished with value: 38.92216365830163 and parameters: {'learning_rate': 0.3422236196850919, 'iterations': 2268, 'depth': 11, 'l2_leaf_reg': 3.594337887308548, 'random_strength': 3.9462567038878205, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.0883753761198997, 'early_stopping_rounds': 966}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:51,890] Trial 496 finished with value: 38.9378729910281 and parameters: {'learning_rate': 0.28184099134406576, 'iterations': 2793, 'depth': 14, 'l2_leaf_reg': 2.755113289240029, 'random_strength': 2.720575954168355, 'bootstrap_type': 'Bayesian', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08239298719509311, 'bagging_temperature': 0.04016174691465224, 'early_stopping_rounds': 999}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:44:56,639] Trial 497 finished with value: 38.91909935632295 and parameters: {'learning_rate': 0.4339743240899392, 'iterations': 4388, 'depth': 10, 'l2_leaf_reg': 1.5673247221294806, 'random_strength': 5.195574176079292, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09485420968250587, 'early_stopping_rounds': 868}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:45:00,738] Trial 498 finished with value: 38.93823116063996 and parameters: {'learning_rate': 0.1458636257006383, 'iterations': 815, 'depth': 12, 'l2_leaf_reg': 3.3208034734522824, 'random_strength': 3.8840079118870916, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.09115181579555835, 'early_stopping_rounds': 937}. Best is trial 2 with value: 38.67168122802259.
# [I 2025-02-17 18:45:05,104] Trial 499 finished with value: 38.93852538954814 and parameters: {'learning_rate': 0.09213471336855181, 'iterations': 2042, 'depth': 11, 'l2_leaf_reg': 6.181694959889929, 'random_strength': 23.686760471302215, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.08563527391039297, 'early_stopping_rounds': 255}. Best is trial 2 with value: 38.67168122802259.
# =========================
# Number of finished trials: 500
# Best trial: 2
# Best value (RMSE): 38.67168122802259
# Best hyperparameters: {'learning_rate': 0.24665670782486956, 'iterations': 4469, 'depth': 12, 'l2_leaf_reg': 5.788398385844328, 'random_strength': 35.169068482278604, 'bootstrap_type': 'MVS', 'boosting_type': 'Plain', 'colsample_bylevel': 0.04811465917313007, 'early_stopping_rounds': 245}
# CPU times: total: 14h 26min 46s
# Wall time: 10h 57min 23s
# {'learning_rate': 0.24665670782486956,
#  'iterations': 4469,
#  'depth': 12,
#  'l2_leaf_reg': 5.788398385844328,
#  'random_strength': 35.169068482278604,
#  'bootstrap_type': 'MVS',
#  'boosting_type': 'Plain',
#  'colsample_bylevel': 0.04811465917313007,
#  'early_stopping_rounds': 245,
#  'random_state': 42,
#  'verbose': 0}

# %%
for i, (train_fold, val_fold) in enumerate(data_splits, 1):
    break

final_model = CatBoostRegressor(**best_params)
final_model.fit(
    train_fold[features], 
    train_fold[target], 
    # cat_features=cat_feature_indexes,  # remove or adjust if you don't have categorical features
    verbose=0
)

feature_importances = final_model.get_feature_importance()

# Create a DataFrame for easy visualization
feat_imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=True)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(feat_imp_df['Feature'], feat_imp_df['Importance'], color='skyblue')
plt.xlabel('Importance Score')
plt.title('Feature Importance for the Best CatBoost Model')
plt.tight_layout()
plt.show()

# %%
feature_importances
# Out:
# array([ 6.58272533,  4.2668661 ,  3.41753314,  4.10408261,  3.99456259,
#         2.47297798,  3.08848136,  4.08554749,  4.1098398 ,  3.18288002,
#        28.40422345,  3.48873128,  2.9618188 ,  3.68252765,  4.34456307,
#         3.57995982,  3.82435874,  3.73508638,  3.5371181 ,  3.13611626])

# %%
features
# Out:
# ['weight_capacity',
#  'compartments',
#  'wc_decimal_count',
#  'brand',
#  'color',
#  'laptop_compartment',
#  'is_waterproof',
#  'size',
#  'material',
#  'style',
#  'weight_capacity_te',
#  'compartments_te',
#  'wc_decimal_count_te',
#  'brand_te',
#  'color_te',
#  'laptop_compartment_te',
#  'is_waterproof_te',
#  'size_te',
#  'material_te',
#  'style_te']

# %%
feature_importances = final_model.get_feature_importance()

# Create a DataFrame for easy visualization
feat_imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=True)

# Plot the feature importances as a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(feat_imp_df['Feature'], feat_imp_df['Importance'], color='skyblue')
plt.xlabel('Importance Score')
plt.title('Feature Importance for the Best CatBoost Model')
plt.tight_layout()
plt.show()
